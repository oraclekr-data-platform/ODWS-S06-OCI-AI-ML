# %%
# Upgrade Oracle ADS to pick up latest features and maintain compatibility with Oracle Cloud Infrastructure.

# !pip install -U oracle-ads
# !pip install --upgrade oci
# Out:
# Requirement already satisfied: oracle-ads in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (2.8.9)
# Requirement already satisfied: gitpython>=3.1.2 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from oracle-ads) (3.1.18)
# Requirement already satisfied: jinja2>=2.11.2 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from oracle-ads) (3.0.3)
# Requirement already satisfied: requests in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from oracle-ads) (2.28.1)
# Requirement already satisfied: tqdm>=4.59.0 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from oracle-ads) (4.64.1)
# Requirement already satisfied: scikit-learn>=1.0 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from oracle-ads) (1.1.2)
# Requirement already satisfied: psutil>=5.7.2 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from oracle-ads) (5.9.0)
# Requirement already satisfied: ocifs>=1.1.3 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from oracle-ads) (1.1.3)
# Requirement already satisfied: matplotlib>=3.1.3 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from oracle-ads) (3.5.2)
# Requirement already satisfied: cloudpickle>=1.6.0 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from oracle-ads) (2.0.0)
# Requirement already satisfied: tabulate>=0.8.9 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from oracle-ads) (0.8.10)
# Requirement already satisfied: PyYAML>=6 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from oracle-ads) (6.0.1)
# Requirement already satisfied: pandas<2.1,>1.2.1 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from oracle-ads) (1.4.4)
# Requirement already satisfied: python_jsonschema_objects>=0.3.13 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from oracle-ads) (0.4.1)
# Requirement already satisfied: fsspec>=0.8.7 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from oracle-ads) (2022.7.1)
# Requirement already satisfied: oci>=2.104.3 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from oracle-ads) (2.112.1)
# Requirement already satisfied: asteval>=0.9.25 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from oracle-ads) (0.9.27)
# Requirement already satisfied: numpy>=1.19.2 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from oracle-ads) (1.23.3)
# Requirement already satisfied: cerberus>=1.3.4 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from oracle-ads) (1.3.4)
# Requirement already satisfied: setuptools in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from cerberus>=1.3.4->oracle-ads) (65.5.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from gitpython>=3.1.2->oracle-ads) (4.0.9)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from jinja2>=2.11.2->oracle-ads) (2.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from matplotlib>=3.1.3->oracle-ads) (4.38.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from matplotlib>=3.1.3->oracle-ads) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from matplotlib>=3.1.3->oracle-ads) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from matplotlib>=3.1.3->oracle-ads) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from matplotlib>=3.1.3->oracle-ads) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from matplotlib>=3.1.3->oracle-ads) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from matplotlib>=3.1.3->oracle-ads) (0.11.0)
# Requirement already satisfied: certifi in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from oci>=2.104.3->oracle-ads) (2022.9.24)
# Requirement already satisfied: pytz>=2016.10 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from oci>=2.104.3->oracle-ads) (2022.6)
# Requirement already satisfied: circuitbreaker<2.0.0,>=1.3.1 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from oci>=2.104.3->oracle-ads) (1.4.0)
# Requirement already satisfied: cryptography<42.0.0,>=3.2.1 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from oci>=2.104.3->oracle-ads) (37.0.2)
# Requirement already satisfied: pyOpenSSL<24.0.0,>=17.5.0 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from oci>=2.104.3->oracle-ads) (22.0.0)
# Requirement already satisfied: inflection>=0.2 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from python_jsonschema_objects>=0.3.13->oracle-ads) (0.5.1)
# Requirement already satisfied: Markdown>=2.4 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from python_jsonschema_objects>=0.3.13->oracle-ads) (3.4.1)
# Requirement already satisfied: six>=1.5.2 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from python_jsonschema_objects>=0.3.13->oracle-ads) (1.16.0)
# Requirement already satisfied: jsonschema>=2.3 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from python_jsonschema_objects>=0.3.13->oracle-ads) (4.7.2)
# Requirement already satisfied: joblib>=1.0.0 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from scikit-learn>=1.0->oracle-ads) (1.0.1)
# Requirement already satisfied: scipy>=1.3.2 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from scikit-learn>=1.0->oracle-ads) (1.9.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from scikit-learn>=1.0->oracle-ads) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from requests->oracle-ads) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from requests->oracle-ads) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from requests->oracle-ads) (2.1.1)
# Requirement already satisfied: cffi>=1.12 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from cryptography<42.0.0,>=3.2.1->oci>=2.104.3->oracle-ads) (1.14.6)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.2->oracle-ads) (3.0.5)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from jsonschema>=2.3->python_jsonschema_objects>=0.3.13->oracle-ads) (0.19.2)
# Requirement already satisfied: attrs>=17.4.0 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from jsonschema>=2.3->python_jsonschema_objects>=0.3.13->oracle-ads) (22.1.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from jsonschema>=2.3->python_jsonschema_objects>=0.3.13->oracle-ads) (5.10.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from Markdown>=2.4->python_jsonschema_objects>=0.3.13->oracle-ads) (5.0.0)
# Requirement already satisfied: pycparser in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from cffi>=1.12->cryptography<42.0.0,>=3.2.1->oci>=2.104.3->oracle-ads) (2.21)
# Requirement already satisfied: zipp>=0.5 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from importlib-metadata>=4.4->Markdown>=2.4->python_jsonschema_objects>=0.3.13->oracle-ads) (3.10.0)
# Requirement already satisfied: oci in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (2.112.1)
# Requirement already satisfied: circuitbreaker<2.0.0,>=1.3.1 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from oci) (1.4.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.5.3 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from oci) (2.8.2)
# Requirement already satisfied: pyOpenSSL<24.0.0,>=17.5.0 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from oci) (22.0.0)
# Requirement already satisfied: pytz>=2016.10 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from oci) (2022.6)
# Requirement already satisfied: cryptography<42.0.0,>=3.2.1 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from oci) (37.0.2)
# Requirement already satisfied: certifi in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from oci) (2022.9.24)
# Requirement already satisfied: cffi>=1.12 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from cryptography<42.0.0,>=3.2.1->oci) (1.14.6)
# Requirement already satisfied: six>=1.5 in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from python-dateutil<3.0.0,>=2.5.3->oci) (1.16.0)
# Requirement already satisfied: pycparser in /home/datascience/conda/generalml_p38_cpu_v1/lib/python3.8/site-packages (from cffi>=1.12->cryptography<42.0.0,>=3.2.1->oci) (2.21)

# %% [markdown]
# <font color=gray>Oracle Data Science service sample notebook.
#
# Copyright (c) 2023 Oracle, Inc.  All rights reserved.
# Licensed under the Universal Permissive License v 1.0 as shown at https://oss.oracle.com/licenses/upl.
# </font>
#
# ***
# # <font color=red>Sklearn으로 모델 만들기</font>
# <p style="margin-left:10%; margin-right:10%;">by the <font color=teal> Oracle Cloud Infrastructure Data Science Service Team </font></p>
#
# ***
#
# ## Introduction:
#
# NLP 분석을 수행하는 데에는 다양한 목적이 있습니다. 텍스트 본문의 유사성을 다른 텍스트 본문과 비교할 수도 있고(클러스터링 기술/거리 측정) 텍스트 본문을 구성하는 주제를 찾을 수도 있습니다.
#
# 이 노트북에서는 Oracle Livelabs를 크롤링한 데이터 세트로 Topic Modeling(주제 모델링)을 진행합니다.Topic Modeling(주제 모델링)은 기본 문서 및 텍스트 코퍼스의 단어를 기반으로 "주제"를 밝히려는 프로세스입니다.
#
# 여기서는 LDA(Latent Dirichlet Allocation)로 알려진 주제 모델링 기술을 소개합니다. 또한 학습 모델로 예측할 때 유용할 원시 텍스트의 토큰화, 형태소 분석 및 벡터화와 같은 몇 가지 자연어 처리 기본 사항도 소개합니다.
#
# ---
#
# ## Overview:
# 이 노트북의 개요는 다음과 같습니다.
#
# - 1. 분석에 맞는 형태로 불필요한 데이터를 없애고 적합한 형태로 변형
#
# - 2. **NLTK(Natural Language Toolkit)를 사용한 자연어 처리(NLP)** - 용어 빈도(TF) 및 역 문서 빈도를 통한 토큰화, 불용어 제거, 형태소 분석 및 텍스트 벡터화와 같은 기본 텍스트 처리 방법 소개 (COUNT Vectorizer)
#
# - 3. **LDA를 사용한 토픽 모델링** - LDA(Latent Dirichlet Allocation) 토픽 모델링 기법을 구현합니다.
#
# - 4. **KMeans를 사용한 클러스터링** - LDA를 통해 Topic별 추출된 probability를 feature로 각 livelab을 비슷한 군집끼리 묶어봅니다.
#
# ---

# %%
# 필요 라이브러리 Import

import os
import ocifs
import oci
from ocifs import OCIFileSystem

import json
import base64
import numpy as np
import pandas as pd

import ads
from dask import dataframe as ddf

# %%
RP = os.environ.get("OCI_RESOURCE_PRINCIPAL_VERSION", "UNDEFINED")

if not RP or RP == "UNDEFINED":
    ads.set_auth(auth='api_key')
else:
    ads.set_auth(auth='resource_principal')

# %% [markdown]
# # 1. 데이터 로드 및 Data Cleansing
#
# Bucket에 있는 크롤링 데이터(json) 로드하고 한국어 레코드 삭제

# %% [markdown]
# ## 1) ATP에서 데이터 로딩

# %%
# ADB에서 crawled 데이터 로딩 
# 아래 USER_NAME, PASSWORD, SERVICE_NAME, WALLET_LOCATION을 본인의 ADB 정보로 변경

connection_parameters = {
    "user_name": "admin",
    "password": "Welcome123456!",
    "service_name": "o0mqv2sevcx6gmh9_low",
    "wallet_location": "./Wallet_O0MQV2SEVCX6GMH9.zip",
}

# %%
import pandas as pd
import ads

crawled_parquet_df = pd.DataFrame.ads.read_sql(
    """
    SELECT
    *
    FROM
    LIVELABS
    """,
    connection_parameters=connection_parameters,
)

# %%
crawled_parquet_df.head()
# Out:
#     ID                                                       TITLE                                                                             URL      TYPE                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 DESCRIPTION            DURATION       PUBLISHED_TIME                                        TITLE_KO                                                                                                                                                                                                                                                                                                                                                                                   DESC_KO DURATION_KO                                                                         OCI_PRODUCTS                                                                                                                                                                                                                            KEY_PHRASE
# 0  553  Manage and Monitor Autonomous Database                      https://apexapps.oracle.com/pls/apex/r/dbpm/livelabs/run-workshop?p210_wid=553  Hands-on  The labs in this workshop show you a variety of ways to manage and monitor your Oracle Autonomous Database on Shared Infrastructure (ADB-S). You will provision a new ADB instance, practice connecting to the database securely with and without a connection wallet, examine a variety of ways to monitor database performance and other metrics, apply scaling and auto scaling, enable disaster recovery using Autonomous Data Guard, create refreshable database clones, set event and alarm notifications, and secure your data using Oracle Data Safe.                                                                                                                                                               3 hours             2017-09-02T01:47:14  Autonomous Database 관리 및 모니터링                   이 워크샵의 실습에서는 Oracle Autonomous Database on Shared Infrastructure(ADB-S)를 관리하고 모니터하는 다양한 방법을 보여줍니다. 새 ADB 인스턴스를 프로비저닝하고, 접속 전자 지갑을 사용하거나 사용하지 않고 데이터베이스에 안전하게 접속하는 방법을 연습하고, 데이터베이스 성능 및 기타 측정항목을 모니터하고, 스케일링 및 자동 스케일링을 적용하고, Autonomous Data Guard를 사용하여 재해 복구를 사용으로 설정하고, 새로고침 가능한 데이터베이스 복제본을 생성하고, 이벤트 및 알람 통지를 설정하고, Oracle Data Safe를 사용하여 데이터를 보호할 수 있습니다.                         3시간         refreshable database,adb-s                                                           variety of ways,oracle autonomous database,shared infrastructure,new adb instance,connection wallet,scaling and auto scaling,disaster recovery,using autonomous data guard,refreshable database clones,event and alarm notifications
# 1  554  Low Code Development Oracle APEX on Autonomous Database     https://apexapps.oracle.com/pls/apex/r/dbpm/livelabs/run-workshop?p210_wid=554  Hands-on  Using APEX, developers can quickly develop and deploy compelling apps that solve real problems and provide immediate value. You won't need to be an expert in a vast array of technologies to deliver sophisticated solutions. Focus on solving the problem and let APEX take care of the rest.                                                                                                                                                                                                                                                                                                                                                                                                                             2 hours             2017-09-03T15:32:21  Autonomous Database의 로우 코드 개발 Oracle APEX       개발자는 APEX를 사용하여 실제 문제를 해결하고 즉각적인 가치를 제공하는 강력한 앱을 신속하게 개발 및 배포할 수 있습니다. 정교한 솔루션을 제공하기 위해 방대한 기술의 전문가가 될 필요는 없습니다. 문제 해결에 중점을 두고 APEX에서 나머지 부분을 처리하도록 합니다.                                                                                                                                                                                                                                  2시간         oracle apex,apps,apex                                                                autonomous databaseusing apex,compelling apps,real problems,immediate value,vast array of technologies,sophisticated solutions,developers,apex
# 2  560  Machine Learning on Autonomous Database                     https://apexapps.oracle.com/pls/apex/r/dbpm/livelabs/run-workshop?p210_wid=560  Hands-on  Oracle integrates machine learning across the Oracle stack and the enterprise, fully leveraging Oracle Database and Oracle Autonomous Database.  In this workshop, create a machine learning model and move the model to ADB.  Explore machine learning notebooks and use prediction in applications.                                                                                                                                                                                                                                                                                                                                                                                                                       2 hours             2017-09-04T05:55:07  Autonomous Database의 머신 러닝                      Oracle은 Oracle Database와 Oracle Autonomous Database를 완전히 활용하여 Oracle 스택과 기업 전반에 머신 러닝을 통합합니다. 이 워크샵에서는 머신 러닝 모델을 생성하고 모델을 ADB로 이동합니다. 머신 러닝 노트북을 살펴보고 애플리케이션에서 예측 기능을 사용합니다.                                                                                                                                                                                                              2시간         adb,machine learning notebooks,applications                                          machine learning,autonomous databaseoracle integrates machine,oracle stack,leveraging oracle database,oracle autonomous database,machine learning model,explore machine learning notebooks,enterprise,adb,prediction
# 3  566  Boost Analytics Performance with Oracle Database In-Memory  https://apexapps.oracle.com/pls/apex/r/dbpm/livelabs/run-workshop?p210_wid=566  Hands-on  Oracle Database In-Memory provides a unique dual-format architecture that enables tables to be simultaneously represented in memory using traditional row format and a new in-memory column format. This series of labs uses Oracle Database 21c to demonstrate how Database In-Memory is orders of magnitude faster than the traditional row store. Labs will show how to get started with Database In-Memory, how to populate and administer the IM column store, and how to run queries including joins and aggregations. It also highlights new features available in Oracle Database 21c that improve the performance of JSON applications and allow the contents of the IM column store to be automatically managed.  1 hour, 30 minutes  2017-09-06T02:51:59  Oracle Database In-Memory를 통한 분석 성능 향상          Oracle Database In-Memory는 기존의 행 형식과 새로운 in-memory 열 형식을 사용하여 메모리에 테이블을 동시에 표시할 수 있는 고유한 이중 형식 구조를 제공합니다. 이 실습 시리즈에서는 Oracle Database 21c를 사용하여 Database In-Memory가 기존 행 저장소보다 얼마나 빠른지 보여줍니다. 연습에서는 Database In-Memory를 시작하는 방법, IM 열 저장소를 채우는 방법 및 조인 및 집계를 포함한 query를 실행하는 방법을 보여줍니다. 또한 JSON 애플리케이션의 성능을 개선하고 IM 열 저장소의 콘텐츠를 자동으로 관리할 수 있도록 Oracle Database 21c에서 제공되는 새로운 기능을 강조합니다.  1시간 30분     im                                                                                   oracle database 21c,database in-memory,im column store,analytics performance,unique dual-format architecture,traditional row format,new in-memory column format,series of labs,orders of magnitude,traditional row store
# 4  567  Oracle WebLogic Server Kubernetes Operator Tutorial         https://apexapps.oracle.com/pls/apex/r/dbpm/livelabs/run-workshop?p210_wid=567  Hands-on  This workshop provides the process of moving an existing WebLogic Server application into a Kubernetes cluster on Oracle Cloud Infrastructure in the Oracle Public Cloud.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   1 hour              2017-09-08T04:47:41  Oracle WebLogic Server Kubernetes Operator 자습서  이 워크샵은 기존 WebLogic 서버 애플리케이션을 Oracle Public Cloud의 Oracle Cloud Infrastructure 기반의 Kubernetes 클러스터로 이전하는 프로세스를 제공합니다.                                                                                                                                                                                                                                                                     1시간         oracle cloud,oracle public cloud,weblogic server application,oracle weblogic server  existing weblogic server application,kubernetes cluster,oracle cloud infrastructure,oracle public cloud

# %% [markdown]
# ## 2) Object Storage에서 데이터 로딩

# %%
# Bucket에 있는 크롤링 데이터 import
#아래 BUCKET 주소 변경

#crawled_parquet_df = pd.read_json("oci://crawled-data@apackrsct01/enhanced_livelabs.json")
#crawled_parquet_df.head()
# Out:
#     id                                              title  \
# 0  553             Manage and Monitor Autonomous Database
# 1  554  Low Code Development Oracle APEX on Autonomous...
# 2  560            Machine Learning on Autonomous Database
# 3  566  Boost Analytics Performance with Oracle Databa...
# 4  567  Oracle WebLogic Server Kubernetes Operator Tut...
#
#                                                  url      type  \
# 0  https://apexapps.oracle.com/pls/apex/r/dbpm/li...  Hands-on
# 1  https://apexapps.oracle.com/pls/apex/r/dbpm/li...  Hands-on
# 2  https://apexapps.oracle.com/pls/apex/r/dbpm/li...  Hands-on
# 3  https://apexapps.oracle.com/pls/apex/r/dbpm/li...  Hands-on
# 4  https://apexapps.oracle.com/pls/apex/r/dbpm/li...  Hands-on
#
#                                                 desc            duration  \
# 0  The labs in this workshop show you a variety o...             3 hours
# 1  Using APEX, developers can quickly develop and...             2 hours
# 2  Oracle integrates machine learning across the ...             2 hours
# 3  Oracle Database In-Memory provides a unique du...  1 hour, 30 minutes
# 4  This workshop provides the process of moving a...              1 hour
#
#        published_time                                        title_ko  \
# 0 2017-09-02 01:47:14                   Autonomous Database 관리 및 모니터링
# 1 2017-09-03 15:32:21       Autonomous Database의 로우 코드 개발 Oracle APEX
# 2 2017-09-04 05:55:07                      Autonomous Database의 머신 러닝
# 3 2017-09-06 02:51:59          Oracle Database In-Memory를 통한 분석 성능 향상
# 4 2017-09-08 04:47:41  Oracle WebLogic Server Kubernetes Operator 자습서
#
#                                              desc_ko duration_ko  \
# 0  이 워크샵의 실습에서는 Oracle Autonomous Database on Sha...         3시간
# 1  개발자는 APEX를 사용하여 실제 문제를 해결하고 즉각적인 가치를 제공하는 강력한 ...         2시간
# 2  Oracle은 Oracle Database와 Oracle Autonomous Dat...         2시간
# 3  Oracle Database In-Memory는 기존의 행 형식과 새로운 in-me...     1시간 30분
# 4  이 워크샵은 기존 WebLogic 서버 애플리케이션을 Oracle Public Cl...         1시간
#
#                                         oci_products  \
# 0                         refreshable database,adb-s
# 1                              oracle apex,apps,apex
# 2        adb,machine learning notebooks,applications
# 3                                                 im
# 4  oracle cloud,oracle public cloud,weblogic serv...
#
#                                           key_phrase
# 0  variety of ways,oracle autonomous database,sha...
# 1  autonomous databaseusing apex,compelling apps,...
# 2  machine learning,autonomous databaseoracle int...
# 3  oracle database 21c,database in-memory,im colu...
# 4  existing weblogic server application,kubernete...

# %%
# 한국어 레코드 확인

print (crawled_parquet_df.loc[crawled_parquet_df['ID'] == 3206])
# Out:
#        ID                                                  TITLE                                                                              URL      TYPE                                                                                                                                                             DESCRIPTION DURATION       PUBLISHED_TIME                                  TITLE_KO                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         DESC_KO DURATION_KO OCI_PRODUCTS                                                                                                                                     KEY_PHRASE
# 462  3206  [Korean] Oracle Container for Kubernetes Fundamentals  https://apexapps.oracle.com/pls/apex/r/dbpm/livelabs/run-workshop?p210_wid=3206  Hands-on  이 워크샵을 통해, 여러분은 마이크로서비스를 개발하고, 쿠버네티스에 배포하는 방법을 배우게 됩니다. 더불어 워크샵의 모든 과정이 끝나고 나면, 관리형 쿠버네티스인 오라클 컨테이너 엔진, OKE에 대해서 오픈소스 쿠버네티스에 대한 호환성과 관리형 쿠버네티스로의 사용 편의성도 경험하게 되실 것입니다.  4 hours  2020-08-10T18:56:41  [한국어] Oracle Container for Kubernetes 기초  2014년 1월 20일에 확인함. ↑ 가 나 다 라 마 바 사 아 바 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 2014년 11월 20일에 확인함. ↑ 가 나 다 라 마 바 사 아 바 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아  4시간         None         oracle container,kubernetes fundamentals��� ������������ ������,������������ ������������������������,������������ ������ ������������,korean

# %%
crawled_parquet_df.loc[462]
# Out:
# ID                3206
# TITLE             [Korean] Oracle Container for Kubernetes Fundamentals
# URL               https://apexapps.oracle.com/pls/apex/r/dbpm/livelabs/run-workshop?p210_wid=3206
# TYPE              Hands-on
# DESCRIPTION       이 워크샵을 통해, 여러분은 마이크로서비스를 개발하고, 쿠버네티스에 배포하는 방법을 배우게 됩니다. 더불어 워크샵의 모든 과정이 끝나고 나면, 관리형 쿠버네티스인 오라클 컨테이너 엔진, OKE에 대해서 오픈소스 쿠버네티스에 대한 호환성과 관리형 쿠버네티스로의 사용 편의성도 경험하게 되실 것입니다.
# DURATION          4 hours
# PUBLISHED_TIME    2020-08-10T18:56:41
# TITLE_KO          [한국어] Oracle Container for Kubernetes 기초
# DESC_KO           2014년 1월 20일에 확인함. ↑ 가 나 다 라 마 바 사 아 바 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 2014년 11월 20일에 확인함. ↑ 가 나 다 라 마 바 사 아 바 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아
# DURATION_KO       4시간
# OCI_PRODUCTS      None
# KEY_PHRASE        oracle container,kubernetes fundamentals��� ������������ ������,������������ ������������������������,������������ ������ ������������,korean
# Name: 462, dtype: object

# %%
print (crawled_parquet_df.loc[crawled_parquet_df['ID'] == 3598])
# Out:
#        ID                                TITLE                                                                              URL      TYPE                                                                                                                                                                        DESCRIPTION DURATION       PUBLISHED_TIME                TITLE_KO                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          DESC_KO DURATION_KO OCI_PRODUCTS                                                                              KEY_PHRASE
# 774  3598  [Korean] OCI Functions Fundamentals  https://apexapps.oracle.com/pls/apex/r/dbpm/livelabs/run-workshop?p210_wid=3598  Hands-on  이 워크샵을 통해, 여러분은 서버리스 함수를 이해하고, OCI에서 제공하는 OCI Functions을 개발, 배포, 관리하는 방법을 배우게 됩니다. 더불어 워크샵의 모든 과정이 끝나고 나면, OCI Functions의 기초를 익히고, 고객 요구사항을 반영하기 위해 필요한, OCI 상에서 주요 사용 패턴을 학습합니다.  4 hours  2022-08-19T22:44:40  [한국어] OCI Functions 기초  2014년 1월 20일에 확인함. ↑ 가 나 다 라 마 바 사 아 바 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 2014년 1월 20일에 확인함. ↑ 가 나 다 라 마 바 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아  4시간         None         ������������ ������������ ���������,functions��� ������,korean,������,���������,������

# %%
crawled_parquet_df.loc[774]
# Out:
# ID                3598
# TITLE             [Korean] OCI Functions Fundamentals
# URL               https://apexapps.oracle.com/pls/apex/r/dbpm/livelabs/run-workshop?p210_wid=3598
# TYPE              Hands-on
# DESCRIPTION       이 워크샵을 통해, 여러분은 서버리스 함수를 이해하고, OCI에서 제공하는 OCI Functions을 개발, 배포, 관리하는 방법을 배우게 됩니다. 더불어 워크샵의 모든 과정이 끝나고 나면, OCI Functions의 기초를 익히고, 고객 요구사항을 반영하기 위해 필요한, OCI 상에서 주요 사용 패턴을 학습합니다.
# DURATION          4 hours
# PUBLISHED_TIME    2022-08-19T22:44:40
# TITLE_KO          [한국어] OCI Functions 기초
# DESC_KO           2014년 1월 20일에 확인함. ↑ 가 나 다 라 마 바 사 아 바 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 2014년 1월 20일에 확인함. ↑ 가 나 다 라 마 바 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아 사 아
# DURATION_KO       4시간
# OCI_PRODUCTS      None
# KEY_PHRASE        ������������ ������������ ���������,functions��� ������,korean,������,���������,������
# Name: 774, dtype: object

# %%
print (crawled_parquet_df.loc[crawled_parquet_df['ID'] == 3615])
# Out:
#        ID                                    TITLE                                                                              URL      TYPE                                                                                                                                                                                                     DESCRIPTION DURATION       PUBLISHED_TIME             TITLE_KO DESC_KO DURATION_KO OCI_PRODUCTS                                                                                                           KEY_PHRASE
# 788  3615  [Korean] OCI Core Services Fundamentals  https://apexapps.oracle.com/pls/apex/r/dbpm/livelabs/run-workshop?p210_wid=3615  Hands-on  이 워크샵에서는 네트워킹 - VCN(가상 클라우드 네트워크), 컴퓨트 및 블록 볼륨을 포함하여 OCI(Oracle Cloud Infrastructure) 핵심 서비스에 대한 소개를 다룹니다. 이 워크샵을 통해 OCI Core Services를 사용하여 컴퓨트 인스턴스 VM을 만들어 사용하고, 로드밸런서를 통한 부하 분산, 자동 확장 등을 실습하고 이해할 수 있습니다.  4 hours  2022-10-08T21:12:23  [한국어] OCI 핵심 서비스 기초  None    4시간         None         oci core services fundamentals���,oracle cloud infrastructure,������ ������������,korean,������������,vcn,���������

# %%
crawled_parquet_df.loc[788]
# Out:
# ID                3615
# TITLE             [Korean] OCI Core Services Fundamentals
# URL               https://apexapps.oracle.com/pls/apex/r/dbpm/livelabs/run-workshop?p210_wid=3615
# TYPE              Hands-on
# DESCRIPTION       이 워크샵에서는 네트워킹 - VCN(가상 클라우드 네트워크), 컴퓨트 및 블록 볼륨을 포함하여 OCI(Oracle Cloud Infrastructure) 핵심 서비스에 대한 소개를 다룹니다. 이 워크샵을 통해 OCI Core Services를 사용하여 컴퓨트 인스턴스 VM을 만들어 사용하고, 로드밸런서를 통한 부하 분산, 자동 확장 등을 실습하고 이해할 수 있습니다.
# DURATION          4 hours
# PUBLISHED_TIME    2022-10-08T21:12:23
# TITLE_KO          [한국어] OCI 핵심 서비스 기초
# DESC_KO           None
# DURATION_KO       4시간
# OCI_PRODUCTS      None
# KEY_PHRASE        oci core services fundamentals���,oracle cloud infrastructure,������ ������������,korean,������������,vcn,���������
# Name: 788, dtype: object

# %%
print (crawled_parquet_df.loc[crawled_parquet_df['ID'] == 1067])
# Out:
#        ID          TITLE                                                                              URL      TYPE DESCRIPTION DURATION       PUBLISHED_TIME   TITLE_KO DESC_KO DURATION_KO OCI_PRODUCTS     KEY_PHRASE
# 402  1067  Testing noVNC  https://apexapps.oracle.com/pls/apex/r/dbpm/livelabs/run-workshop?p210_wid=1067  Hands-on  None        3 hours  2020-02-28T12:55:36  noVNC 테스트  None    3시간         None         testing novnc

# %%
crawled_parquet_df.loc[402]
# Out:
# ID                1067
# TITLE             Testing noVNC
# URL               https://apexapps.oracle.com/pls/apex/r/dbpm/livelabs/run-workshop?p210_wid=1067
# TYPE              Hands-on
# DESCRIPTION       None
# DURATION          3 hours
# PUBLISHED_TIME    2020-02-28T12:55:36
# TITLE_KO          noVNC 테스트
# DESC_KO           None
# DURATION_KO       3시간
# OCI_PRODUCTS      None
# KEY_PHRASE        testing novnc
# Name: 402, dtype: object

# %%
print (crawled_parquet_df.loc[crawled_parquet_df['ID'] == 3095])
# Out:
#        ID                                     TITLE                                                                              URL      TYPE    DESCRIPTION DURATION       PUBLISHED_TIME                         TITLE_KO  DESC_KO DURATION_KO OCI_PRODUCTS                KEY_PHRASE
# 409  3095  Testing WMS-LL ORDS Sync - Please Ignore  https://apexapps.oracle.com/pls/apex/r/dbpm/livelabs/run-workshop?p210_wid=3095  Hands-on  override long  None     2020-03-14T22:04:03  WMS-LL ORDS 동기화 테스트 중 - 무시하십시오.  long 대체  None        None         testing wms-ll ords sync

# %%
crawled_parquet_df.loc[409]
# Out:
# ID                3095
# TITLE             Testing WMS-LL ORDS Sync - Please Ignore
# URL               https://apexapps.oracle.com/pls/apex/r/dbpm/livelabs/run-workshop?p210_wid=3095
# TYPE              Hands-on
# DESCRIPTION       override long
# DURATION          None
# PUBLISHED_TIME    2020-03-14T22:04:03
# TITLE_KO          WMS-LL ORDS 동기화 테스트 중 - 무시하십시오.
# DESC_KO           long 대체
# DURATION_KO       None
# OCI_PRODUCTS      None
# KEY_PHRASE        testing wms-ll ords sync
# Name: 409, dtype: object

# %%
#한국어 및 테스트 데이터 삭제 

df_final=crawled_parquet_df.drop([402,409,462,774,788])

# %%
df_final.head()
# Out:
#     ID                                                       TITLE                                                                             URL      TYPE                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 DESCRIPTION            DURATION       PUBLISHED_TIME                                        TITLE_KO                                                                                                                                                                                                                                                                                                                                                                                   DESC_KO DURATION_KO                                                                         OCI_PRODUCTS                                                                                                                                                                                                                            KEY_PHRASE
# 0  553  Manage and Monitor Autonomous Database                      https://apexapps.oracle.com/pls/apex/r/dbpm/livelabs/run-workshop?p210_wid=553  Hands-on  The labs in this workshop show you a variety of ways to manage and monitor your Oracle Autonomous Database on Shared Infrastructure (ADB-S). You will provision a new ADB instance, practice connecting to the database securely with and without a connection wallet, examine a variety of ways to monitor database performance and other metrics, apply scaling and auto scaling, enable disaster recovery using Autonomous Data Guard, create refreshable database clones, set event and alarm notifications, and secure your data using Oracle Data Safe.                                                                                                                                                               3 hours             2017-09-02T01:47:14  Autonomous Database 관리 및 모니터링                   이 워크샵의 실습에서는 Oracle Autonomous Database on Shared Infrastructure(ADB-S)를 관리하고 모니터하는 다양한 방법을 보여줍니다. 새 ADB 인스턴스를 프로비저닝하고, 접속 전자 지갑을 사용하거나 사용하지 않고 데이터베이스에 안전하게 접속하는 방법을 연습하고, 데이터베이스 성능 및 기타 측정항목을 모니터하고, 스케일링 및 자동 스케일링을 적용하고, Autonomous Data Guard를 사용하여 재해 복구를 사용으로 설정하고, 새로고침 가능한 데이터베이스 복제본을 생성하고, 이벤트 및 알람 통지를 설정하고, Oracle Data Safe를 사용하여 데이터를 보호할 수 있습니다.                         3시간         refreshable database,adb-s                                                           variety of ways,oracle autonomous database,shared infrastructure,new adb instance,connection wallet,scaling and auto scaling,disaster recovery,using autonomous data guard,refreshable database clones,event and alarm notifications
# 1  554  Low Code Development Oracle APEX on Autonomous Database     https://apexapps.oracle.com/pls/apex/r/dbpm/livelabs/run-workshop?p210_wid=554  Hands-on  Using APEX, developers can quickly develop and deploy compelling apps that solve real problems and provide immediate value. You won't need to be an expert in a vast array of technologies to deliver sophisticated solutions. Focus on solving the problem and let APEX take care of the rest.                                                                                                                                                                                                                                                                                                                                                                                                                             2 hours             2017-09-03T15:32:21  Autonomous Database의 로우 코드 개발 Oracle APEX       개발자는 APEX를 사용하여 실제 문제를 해결하고 즉각적인 가치를 제공하는 강력한 앱을 신속하게 개발 및 배포할 수 있습니다. 정교한 솔루션을 제공하기 위해 방대한 기술의 전문가가 될 필요는 없습니다. 문제 해결에 중점을 두고 APEX에서 나머지 부분을 처리하도록 합니다.                                                                                                                                                                                                                                  2시간         oracle apex,apps,apex                                                                autonomous databaseusing apex,compelling apps,real problems,immediate value,vast array of technologies,sophisticated solutions,developers,apex
# 2  560  Machine Learning on Autonomous Database                     https://apexapps.oracle.com/pls/apex/r/dbpm/livelabs/run-workshop?p210_wid=560  Hands-on  Oracle integrates machine learning across the Oracle stack and the enterprise, fully leveraging Oracle Database and Oracle Autonomous Database.  In this workshop, create a machine learning model and move the model to ADB.  Explore machine learning notebooks and use prediction in applications.                                                                                                                                                                                                                                                                                                                                                                                                                       2 hours             2017-09-04T05:55:07  Autonomous Database의 머신 러닝                      Oracle은 Oracle Database와 Oracle Autonomous Database를 완전히 활용하여 Oracle 스택과 기업 전반에 머신 러닝을 통합합니다. 이 워크샵에서는 머신 러닝 모델을 생성하고 모델을 ADB로 이동합니다. 머신 러닝 노트북을 살펴보고 애플리케이션에서 예측 기능을 사용합니다.                                                                                                                                                                                                              2시간         adb,machine learning notebooks,applications                                          machine learning,autonomous databaseoracle integrates machine,oracle stack,leveraging oracle database,oracle autonomous database,machine learning model,explore machine learning notebooks,enterprise,adb,prediction
# 3  566  Boost Analytics Performance with Oracle Database In-Memory  https://apexapps.oracle.com/pls/apex/r/dbpm/livelabs/run-workshop?p210_wid=566  Hands-on  Oracle Database In-Memory provides a unique dual-format architecture that enables tables to be simultaneously represented in memory using traditional row format and a new in-memory column format. This series of labs uses Oracle Database 21c to demonstrate how Database In-Memory is orders of magnitude faster than the traditional row store. Labs will show how to get started with Database In-Memory, how to populate and administer the IM column store, and how to run queries including joins and aggregations. It also highlights new features available in Oracle Database 21c that improve the performance of JSON applications and allow the contents of the IM column store to be automatically managed.  1 hour, 30 minutes  2017-09-06T02:51:59  Oracle Database In-Memory를 통한 분석 성능 향상          Oracle Database In-Memory는 기존의 행 형식과 새로운 in-memory 열 형식을 사용하여 메모리에 테이블을 동시에 표시할 수 있는 고유한 이중 형식 구조를 제공합니다. 이 실습 시리즈에서는 Oracle Database 21c를 사용하여 Database In-Memory가 기존 행 저장소보다 얼마나 빠른지 보여줍니다. 연습에서는 Database In-Memory를 시작하는 방법, IM 열 저장소를 채우는 방법 및 조인 및 집계를 포함한 query를 실행하는 방법을 보여줍니다. 또한 JSON 애플리케이션의 성능을 개선하고 IM 열 저장소의 콘텐츠를 자동으로 관리할 수 있도록 Oracle Database 21c에서 제공되는 새로운 기능을 강조합니다.  1시간 30분     im                                                                                   oracle database 21c,database in-memory,im column store,analytics performance,unique dual-format architecture,traditional row format,new in-memory column format,series of labs,orders of magnitude,traditional row store
# 4  567  Oracle WebLogic Server Kubernetes Operator Tutorial         https://apexapps.oracle.com/pls/apex/r/dbpm/livelabs/run-workshop?p210_wid=567  Hands-on  This workshop provides the process of moving an existing WebLogic Server application into a Kubernetes cluster on Oracle Cloud Infrastructure in the Oracle Public Cloud.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   1 hour              2017-09-08T04:47:41  Oracle WebLogic Server Kubernetes Operator 자습서  이 워크샵은 기존 WebLogic 서버 애플리케이션을 Oracle Public Cloud의 Oracle Cloud Infrastructure 기반의 Kubernetes 클러스터로 이전하는 프로세스를 제공합니다.                                                                                                                                                                                                                                                                     1시간         oracle cloud,oracle public cloud,weblogic server application,oracle weblogic server  existing weblogic server application,kubernetes cluster,oracle cloud infrastructure,oracle public cloud

# %% [markdown]
# ---

# %% [markdown]
# # 2. Natural Language Processing(자연어 처리)
#
# NLP(Natural Language Processing, 자연어 처리)는 인공지능의 한 분야로서 머신러닝을 사용하여 텍스트와 데이터를 처리하고 해석합니다. 자연어 처리를 위해서는 원시 텍스트를 모델과 시스템에서 읽을 수 있는 형식으로 변환하기 위한 몇 가지 사전 처리 단계가 필요합니다.
#
# 1. **Tokenization(토큰화)** - 텍스트를 개별 구성 단어로 분리합니다.
# 2. **Stopwords(불용어 처리)** - 너무 자주 발생하는 단어는 삭제합니다. 발생 빈도가 관련 텍스트를 감지하는 데 도움이 되지 않습니다.(매우 드물게 발생하는 단어를 버리는 것도 고려하세요).
# 3. **Stemmization(어간 추출)** - 변형된 단어를 동일한 의미를 전달하는 단일 상위 단어로 결합합니다.
# 4. **Vectorization(벡터화)** - 텍스트를 벡터 형식으로 변환합니다. 간단한 방식 중 하나는 bag-of-words 접근 방식(단어 빈도 저장)입니다.

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/datascience/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ## 2a. Tokenization(토큰화)
#
# 토큰화의 개념은 주어진 문서에서 일련의 문자를 취하여 이 방법의 시조 "토큰"인 개별 구성 조각으로 나누는 행위입니다.
#
# "word_tokenize( )"(TreebankWord 토크나이저)라는 편리한 방법이 있습니다. 이 방법은 단수 단어와 문장 부호를 다음과 같이 자동으로 별도의 요소로 제거합니다.

# %%
first_text = df_final.DESCRIPTION[0]
first_text_list = nltk.word_tokenize(first_text)
print(first_text)
print("="*90)
print(first_text_list)
# Out:
# The labs in this workshop show you a variety of ways to manage and monitor your Oracle Autonomous Database on Shared Infrastructure (ADB-S). You will provision a new ADB instance, practice connecting to the database securely with and without a connection wallet, examine a variety of ways to monitor database performance and other metrics, apply scaling and auto scaling, enable disaster recovery using Autonomous Data Guard, create refreshable database clones, set event and alarm notifications, and secure your data using Oracle Data Safe.
# ==========================================================================================
# ['The', 'labs', 'in', 'this', 'workshop', 'show', 'you', 'a', 'variety', 'of', 'ways', 'to', 'manage', 'and', 'monitor', 'your', 'Oracle', 'Autonomous', 'Database', 'on', 'Shared', 'Infrastructure', '(', 'ADB-S', ')', '.', 'You', 'will', 'provision', 'a', 'new', 'ADB', 'instance', ',', 'practice', 'connecting', 'to', 'the', 'database', 'securely', 'with', 'and', 'without', 'a', 'connection', 'wallet', ',', 'examine', 'a', 'variety', 'of', 'ways', 'to', 'monitor', 'database', 'performance', 'and', 'other', 'metrics', ',', 'apply', 'scaling', 'and', 'auto', 'scaling', ',', 'enable', 'disaster', 'recovery', 'using', 'Autonomous', 'Data', 'Guard', ',', 'create', 'refreshable', 'database', 'clones', ',', 'set', 'event', 'and', 'alarm', 'notifications', ',', 'and', 'secure', 'your', 'data', 'using', 'Oracle', 'Data', 'Safe', '.']

# %% [markdown]
# ## 2b. 불용어 제거
#
# 불용어는 학습 또는 예측 프로세스에 실제로 크게 기여하지 않는 말뭉치에서 매우 일반적이고 높은 빈도로 나타나는 단어입니다.
#
# 불용어에는 "to" 또는 "the"와 같은 용어가 포함되어 있으므로 사전 처리 단계에서 이러한 용어를 제거하는 것이 좋습니다.
#
# 편리하게도 NLTK는 사전 정의된 153개의 영어 불용어 목록과 함께 제공됩니다.

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/datascience/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopwords = nltk.corpus.stopwords.words('english')
len(stopwords)
print(stopwords)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
first_text_list_cleaned = [word for word in first_text_list if word.lower() not in stopwords]
second_text_list_cleaned = [word.lower() for word in first_text_list_cleaned if word.isalpha()]

print(second_text_list_cleaned)
print("="*90)
print("Length of original list: {0} words\n"
      "Length of list after stopwords removal: {1} words"
      .format(len(first_text_list), len(second_text_list_cleaned)))
# Out:
# ['labs', 'workshop', 'show', 'variety', 'ways', 'manage', 'monitor', 'oracle', 'autonomous', 'database', 'shared', 'infrastructure', 'provision', 'new', 'adb', 'instance', 'practice', 'connecting', 'database', 'securely', 'without', 'connection', 'wallet', 'examine', 'variety', 'ways', 'monitor', 'database', 'performance', 'metrics', 'apply', 'scaling', 'auto', 'scaling', 'enable', 'disaster', 'recovery', 'using', 'autonomous', 'data', 'guard', 'create', 'refreshable', 'database', 'clones', 'set', 'event', 'alarm', 'notifications', 'secure', 'data', 'using', 'oracle', 'data', 'safe']
# ==========================================================================================
# Length of original list: 94 words
# Length of list after stopwords removal: 55 words

# %% [markdown]
# ## 2c. Stemming & Lemmatization(형태소 분석 및 원형 추출)
#
# 불용어를 제거한 후 소개하고 싶은 NLP의 다음 단계는 어간 추출 과정입니다. 이 단계에서의 작업은 유사한 단어의 다양한 변형을 단일 용어로 줄이려고 시도합니다(다양한 변형이 모두 단일 단어 *Stem*으로 축소됨).
#
# 예를 들어 "running", "runs" 및 "run"이 있는 경우 이 세 단어가 "run"이라는 단어로 축소시켜야 합니다. Porter, lancaster, Snowball 등 다양한 형태소 분석기를 사용할 수 있습니다. 아래 예시에서는 Porter Stemmer를 사용하였습니다.

# %%
stemmer = nltk.stem.PorterStemmer()
print("The stemmed form of running is: {}".format(stemmer.stem("running")))
print("The stemmed form of runs is: {}".format(stemmer.stem("runs")))
print("The stemmed form of run is: {}".format(stemmer.stem("run")))
# Out:
# The stemmed form of running is: run
# The stemmed form of runs is: run
# The stemmed form of run is: run

# %% [markdown]
# stemmer는 위에 주어진 단어를 기본 형식으로 줄였습니다. 이 단계는 텍스트 학습 및 분류 작업을 할 때 단어 데이터 세트의 크기를 줄이는 데 가장 큰 도움이 됩니다. 그러나 형태소 분석 과정에서는 단어를 축소할 때 어휘 또는 단어 형식을 고려하지 않는다는 단점이 있습니다.
#
# 아래는 leaves의 형태소 분석 결과입니다. leaves의 원형은 leaf이지만 아래의 결과는 leaves의 'es'를 단어의 복수형으로 파악하여 잘못된 원형을 도출한 것을 알 수 있습니다.

# %%
print("The stemmed form of leaves is: {}".format(stemmer.stem("leaves")))
# Out:
# The stemmed form of leaves is: leav

# %% [markdown]
# ### Lemmatization(어간 추출)
#
# 따라서 이를 보완할 수 있는 방법을 사용하는데 이는 lemmatization입니다. Lemmatization은 형태소 분석기와는 달리 실제 사전이나 어휘(Lemma)를 기반으로 단어를 줄이는 것을 목표로 하기 때문에 어휘 의미를 갖지 않는 형태소 형태로 자르지 않습니다. 여기에서 NLTK를 다시 한 번 활용하여 lemmatizer(WordNet 변형)를 초기화하고 다음과 같이 단어를 축소시킬 수 있습니다.

# %%
import nltk
nltk.download('omw-1.4')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /home/datascience/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/datascience/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer
lemm = WordNetLemmatizer()
print("The lemmatized form of leaves is: {}".format(lemm.lemmatize("leaves")))
# Out:
# The lemmatized form of leaves is: leaf

# %% [markdown]
# 위 예에서 알 수 있듯이 lemmatizer는 단어를 훨씬 더 어휘적으로 이해되는 형식으로 축소하는 것을 볼 수 있습니다.

# %% [markdown]
# ## 2d. Vectorization(원시 텍스트 벡터화)
#
# 위에서 세 가지 단계에 대해 얘기했습니다. 그러나 이 형태는 사람이 읽을 수 있는 형태이지, 기계가 읽을 수 있는 형태는 아닙니다. 기계는 비트와 숫자를 읽을 수 있으므로 먼저 Bag-of-Words로 알려진 매우 일반적인 접근 방식을 활용하여 텍스트를 숫자로 변환해야 합니다.
#
# ---
#
# **Bag of Words 접근 방식**
#
# 이 접근 방식은 단어 수를 시작 블록으로 사용하고 특정 단어에 특정한 벡터에 각 단어의 빈도를 기록합니다.
#
# 예를 들어 "I love to eat Burgers", "I love to eat Fries"라는 두 문장이 주어지면 먼저 토큰화하여 단어 수를 얻을 수 있는 6개 단어의 어휘를 얻습니다.[I, love, to, eat , Burgers, Fries]
#
# Bag of Words 접근 방식을 통해 텍스트를 벡터화하면 각 단어에 대해 6개의 고유한 벡터가 생기고, 각 단어는 이 새로운 변환 데이터 세트에서 개별 기능/열이 됩니다.
#
# 아래 예시를 통해 Scikit-learn 라이브러리를 활용하여 다음과 같이 CountVectorizer 메서드를 통해 단어 수(용어 빈도)의 벡터를 생성하는 벡터화기를 구현합니다.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

sentence = ["I love to eat Burgers", 
            "I love to eat Fries"]
vectorizer = CountVectorizer(min_df=0)
sentence_transform = vectorizer.fit_transform(sentence)

# %% [markdown]
# **vectorizer를 데이터 세트에 Fitting**
#
# 먼저 "벡터화기"라고 하는 CountVectorizer 함수를 통해 간단한 용어 빈도 객체를 초기화하고 생성합니다. 여기에서 매개변수 "min_df"는 최소 문서 빈도를 나타내며 벡터화기는 해당 값보다 적게 발생하는 모든 단어를 삭제합니다. 이 방법과 사용할 수 있는 나머지 매개변수에 대한 자세한 내용은 [Sklearn 웹사이트](http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction을 참조하세요. .text.CountVectorizer.html).
#
# 마지막으로 fit_transform 메서드를 적용하는 것은 실제로 두 단계로 구성됩니다. 첫 번째 단계는 벡터라이저가 제공하는 데이터 세트에 매핑되는 방법입니다. 이 작업이 완료되면 아래와 같이 원시 텍스트가 벡터 형식으로 변환되는 변환 메서드를 통해 실제 벡터화 작업이 수행됩니다.

# %%
print("The features are:\n {}".format(vectorizer.get_feature_names()))
print("\nThe vectorized array looks like:\n {}".format(sentence_transform.toarray()))
# Out:
# The features are:
#  ['burgers', 'eat', 'fries', 'love', 'to']
#
# The vectorized array looks like:
#  [[1 1 0 1 1]
#  [0 1 1 1 1]]

# %%
sentence_transform
# Out:
# <2x5 sparse matrix of type '<class 'numpy.int64'>'
# 	with 8 stored elements in Compressed Sparse Row format>

# %% [markdown]
# **Sparse matrix vector ouputs**
#
# 벡터화된 텍스트에서 feature는 벡터화기에 입력된 텍스트의 단어로 구성되어 있음을 알 수 있습니다. 벡터화기에 get_feature_names 특성을 호출하여 확인하면 됩니다. 변환된 텍스트를 확인하기 위해 sentence_transform을 호출하면 "*sparse matrix of type class 'numpy.int64' with 8 stored elements in Compressed Sparse Row format*"라는 메시지가 표시됩니다. 이것은 벡터라이저가 변환된 원시 텍스트를 대부분의 값이 0이거나 거의 무시할 수 있는 행렬로 반환한다는 것을 의미하므로 sparse라는 용어가 사용됩니다.

# %% [markdown]
# ---

# %% [markdown]
# # 3. Topic Modeling(주제 모델링)
#
# 이 장에서는 주제 모델링 기술을 구현할 것입니다.
#
# **Latent Dirichlet Allocation** - 말뭉치의 단어에 가중치를 할당하여 데이터 세트에 잠재된 주제를 발견하는 확률적 생성 모델입니다. 여기서 각 주제는 각 단어에 다른 확률 가중치를 할당합니다.

# %% [markdown]
# ## 3a. 모든 전처리 단계 통합
#
# 이전 섹션에서 언급된 모든 텍스트 전처리 단계를 통합해서 처리합니다. CountVectorizer를 사용하여 원시 텍스트를 벡터화하면 토큰화 및 불용어 필터링의 이중 단계가 자동으로 고급 구성 요소로 포함됩니다. 이전 섹션 2a에서 소개한 NLTK 토크나이저와 달리 Sklearn의 토크나이저는 기본적으로 모든 단일 문자 용어('a', 'w' 등) 및 소문자도 버립니다.
#
# vectorizer에는 기본 제공 lemmatizer가 없으므로 이를 구현해야 합니다. 아래 코드와 같이 "build_analyzer" 메서드를 오버라이드해서 CountVectorizer 클래스를 확장할 수 있습니다.
#
# ### CountVectorizer 클래스 확장 with Lemmatizer

# %%
lemm = WordNetLemmatizer()
class LemmaCountVectorizer(CountVectorizer):
    def build_analyzer(self):
        analyzer = super(LemmaCountVectorizer, self).build_analyzer()
        return lambda doc: (lemm.lemmatize(w) for w in analyzer(doc))

# %% [markdown]
# 원본 Sklearn의 CountVectorizer 클래스를 상속하고 하위 클래스로 분류했으며 원시 텍스트 행렬의 각 목록에 대한 Lemmatizer를 구현하여 build_analyzer 메서드를 오버라이드하였습니다.

# %%
df_final.head()
# Out:
#     ID                                                       TITLE                                                                             URL      TYPE                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 DESCRIPTION            DURATION       PUBLISHED_TIME                                        TITLE_KO                                                                                                                                                                                                                                                                                                                                                                                   DESC_KO DURATION_KO                                                                         OCI_PRODUCTS                                                                                                                                                                                                                            KEY_PHRASE
# 0  553  Manage and Monitor Autonomous Database                      https://apexapps.oracle.com/pls/apex/r/dbpm/livelabs/run-workshop?p210_wid=553  Hands-on  The labs in this workshop show you a variety of ways to manage and monitor your Oracle Autonomous Database on Shared Infrastructure (ADB-S). You will provision a new ADB instance, practice connecting to the database securely with and without a connection wallet, examine a variety of ways to monitor database performance and other metrics, apply scaling and auto scaling, enable disaster recovery using Autonomous Data Guard, create refreshable database clones, set event and alarm notifications, and secure your data using Oracle Data Safe.                                                                                                                                                               3 hours             2017-09-02T01:47:14  Autonomous Database 관리 및 모니터링                   이 워크샵의 실습에서는 Oracle Autonomous Database on Shared Infrastructure(ADB-S)를 관리하고 모니터하는 다양한 방법을 보여줍니다. 새 ADB 인스턴스를 프로비저닝하고, 접속 전자 지갑을 사용하거나 사용하지 않고 데이터베이스에 안전하게 접속하는 방법을 연습하고, 데이터베이스 성능 및 기타 측정항목을 모니터하고, 스케일링 및 자동 스케일링을 적용하고, Autonomous Data Guard를 사용하여 재해 복구를 사용으로 설정하고, 새로고침 가능한 데이터베이스 복제본을 생성하고, 이벤트 및 알람 통지를 설정하고, Oracle Data Safe를 사용하여 데이터를 보호할 수 있습니다.                         3시간         refreshable database,adb-s                                                           variety of ways,oracle autonomous database,shared infrastructure,new adb instance,connection wallet,scaling and auto scaling,disaster recovery,using autonomous data guard,refreshable database clones,event and alarm notifications
# 1  554  Low Code Development Oracle APEX on Autonomous Database     https://apexapps.oracle.com/pls/apex/r/dbpm/livelabs/run-workshop?p210_wid=554  Hands-on  Using APEX, developers can quickly develop and deploy compelling apps that solve real problems and provide immediate value. You won't need to be an expert in a vast array of technologies to deliver sophisticated solutions. Focus on solving the problem and let APEX take care of the rest.                                                                                                                                                                                                                                                                                                                                                                                                                             2 hours             2017-09-03T15:32:21  Autonomous Database의 로우 코드 개발 Oracle APEX       개발자는 APEX를 사용하여 실제 문제를 해결하고 즉각적인 가치를 제공하는 강력한 앱을 신속하게 개발 및 배포할 수 있습니다. 정교한 솔루션을 제공하기 위해 방대한 기술의 전문가가 될 필요는 없습니다. 문제 해결에 중점을 두고 APEX에서 나머지 부분을 처리하도록 합니다.                                                                                                                                                                                                                                  2시간         oracle apex,apps,apex                                                                autonomous databaseusing apex,compelling apps,real problems,immediate value,vast array of technologies,sophisticated solutions,developers,apex
# 2  560  Machine Learning on Autonomous Database                     https://apexapps.oracle.com/pls/apex/r/dbpm/livelabs/run-workshop?p210_wid=560  Hands-on  Oracle integrates machine learning across the Oracle stack and the enterprise, fully leveraging Oracle Database and Oracle Autonomous Database.  In this workshop, create a machine learning model and move the model to ADB.  Explore machine learning notebooks and use prediction in applications.                                                                                                                                                                                                                                                                                                                                                                                                                       2 hours             2017-09-04T05:55:07  Autonomous Database의 머신 러닝                      Oracle은 Oracle Database와 Oracle Autonomous Database를 완전히 활용하여 Oracle 스택과 기업 전반에 머신 러닝을 통합합니다. 이 워크샵에서는 머신 러닝 모델을 생성하고 모델을 ADB로 이동합니다. 머신 러닝 노트북을 살펴보고 애플리케이션에서 예측 기능을 사용합니다.                                                                                                                                                                                                              2시간         adb,machine learning notebooks,applications                                          machine learning,autonomous databaseoracle integrates machine,oracle stack,leveraging oracle database,oracle autonomous database,machine learning model,explore machine learning notebooks,enterprise,adb,prediction
# 3  566  Boost Analytics Performance with Oracle Database In-Memory  https://apexapps.oracle.com/pls/apex/r/dbpm/livelabs/run-workshop?p210_wid=566  Hands-on  Oracle Database In-Memory provides a unique dual-format architecture that enables tables to be simultaneously represented in memory using traditional row format and a new in-memory column format. This series of labs uses Oracle Database 21c to demonstrate how Database In-Memory is orders of magnitude faster than the traditional row store. Labs will show how to get started with Database In-Memory, how to populate and administer the IM column store, and how to run queries including joins and aggregations. It also highlights new features available in Oracle Database 21c that improve the performance of JSON applications and allow the contents of the IM column store to be automatically managed.  1 hour, 30 minutes  2017-09-06T02:51:59  Oracle Database In-Memory를 통한 분석 성능 향상          Oracle Database In-Memory는 기존의 행 형식과 새로운 in-memory 열 형식을 사용하여 메모리에 테이블을 동시에 표시할 수 있는 고유한 이중 형식 구조를 제공합니다. 이 실습 시리즈에서는 Oracle Database 21c를 사용하여 Database In-Memory가 기존 행 저장소보다 얼마나 빠른지 보여줍니다. 연습에서는 Database In-Memory를 시작하는 방법, IM 열 저장소를 채우는 방법 및 조인 및 집계를 포함한 query를 실행하는 방법을 보여줍니다. 또한 JSON 애플리케이션의 성능을 개선하고 IM 열 저장소의 콘텐츠를 자동으로 관리할 수 있도록 Oracle Database 21c에서 제공되는 새로운 기능을 강조합니다.  1시간 30분     im                                                                                   oracle database 21c,database in-memory,im column store,analytics performance,unique dual-format architecture,traditional row format,new in-memory column format,series of labs,orders of magnitude,traditional row store
# 4  567  Oracle WebLogic Server Kubernetes Operator Tutorial         https://apexapps.oracle.com/pls/apex/r/dbpm/livelabs/run-workshop?p210_wid=567  Hands-on  This workshop provides the process of moving an existing WebLogic Server application into a Kubernetes cluster on Oracle Cloud Infrastructure in the Oracle Public Cloud.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   1 hour              2017-09-08T04:47:41  Oracle WebLogic Server Kubernetes Operator 자습서  이 워크샵은 기존 WebLogic 서버 애플리케이션을 Oracle Public Cloud의 Oracle Cloud Infrastructure 기반의 Kubernetes 클러스터로 이전하는 프로세스를 제공합니다.                                                                                                                                                                                                                                                                     1시간         oracle cloud,oracle public cloud,weblogic server application,oracle weblogic server  existing weblogic server application,kubernetes cluster,oracle cloud infrastructure,oracle public cloud

# %%
# nan과 null 데이터 처리를 위해 desc열만 dataframe으로 변환 

pd.set_option('display.max_rows',None)
df_final1 = pd.DataFrame({'document':df_final.DESCRIPTION})
df_final1.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      document
# 0  The labs in this workshop show you a variety of ways to manage and monitor your Oracle Autonomous Database on Shared Infrastructure (ADB-S). You will provision a new ADB instance, practice connecting to the database securely with and without a connection wallet, examine a variety of ways to monitor database performance and other metrics, apply scaling and auto scaling, enable disaster recovery using Autonomous Data Guard, create refreshable database clones, set event and alarm notifications, and secure your data using Oracle Data Safe.
# 1  Using APEX, developers can quickly develop and deploy compelling apps that solve real problems and provide immediate value. You won't need to be an expert in a vast array of technologies to deliver sophisticated solutions. Focus on solving the problem and let APEX take care of the rest.
# 2  Oracle integrates machine learning across the Oracle stack and the enterprise, fully leveraging Oracle Database and Oracle Autonomous Database.  In this workshop, create a machine learning model and move the model to ADB.  Explore machine learning notebooks and use prediction in applications.
# 3  Oracle Database In-Memory provides a unique dual-format architecture that enables tables to be simultaneously represented in memory using traditional row format and a new in-memory column format. This series of labs uses Oracle Database 21c to demonstrate how Database In-Memory is orders of magnitude faster than the traditional row store. Labs will show how to get started with Database In-Memory, how to populate and administer the IM column store, and how to run queries including joins and aggregations. It also highlights new features available in Oracle Database 21c that improve the performance of JSON applications and allow the contents of the IM column store to be automatically managed.
# 4  This workshop provides the process of moving an existing WebLogic Server application into a Kubernetes cluster on Oracle Cloud Infrastructure in the Oracle Public Cloud.

# %%
# NaN 레코드 지우기

df_final2 = df_final1.dropna()
print(df_final1.shape)
print(df_final2.shape)
# Out:
# (856, 1)
# (525, 1)

# %%
# null 레코드 지우기

df_final3 = df_final2[df_final2['document'].astype(bool)]
print(df_final1.shape)
print(df_final3.shape)
# Out:
# (856, 1)
# (525, 1)

# %%
# 최종 dataframe를 list에 저장

text = list(df_final3.document.values)
type(text)
# Out:
# list

# %%
# Countvectorizer 호출
    
tf_vectorizer = LemmaCountVectorizer(max_df=0.95, 
                                     min_df=2,
                                     stop_words='english',
                                     decode_error='ignore')
tf = tf_vectorizer.fit_transform(text)

# %%
df_final3.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      document
# 0  The labs in this workshop show you a variety of ways to manage and monitor your Oracle Autonomous Database on Shared Infrastructure (ADB-S). You will provision a new ADB instance, practice connecting to the database securely with and without a connection wallet, examine a variety of ways to monitor database performance and other metrics, apply scaling and auto scaling, enable disaster recovery using Autonomous Data Guard, create refreshable database clones, set event and alarm notifications, and secure your data using Oracle Data Safe.
# 1  Using APEX, developers can quickly develop and deploy compelling apps that solve real problems and provide immediate value. You won't need to be an expert in a vast array of technologies to deliver sophisticated solutions. Focus on solving the problem and let APEX take care of the rest.
# 2  Oracle integrates machine learning across the Oracle stack and the enterprise, fully leveraging Oracle Database and Oracle Autonomous Database.  In this workshop, create a machine learning model and move the model to ADB.  Explore machine learning notebooks and use prediction in applications.
# 3  Oracle Database In-Memory provides a unique dual-format architecture that enables tables to be simultaneously represented in memory using traditional row format and a new in-memory column format. This series of labs uses Oracle Database 21c to demonstrate how Database In-Memory is orders of magnitude faster than the traditional row store. Labs will show how to get started with Database In-Memory, how to populate and administer the IM column store, and how to run queries including joins and aggregations. It also highlights new features available in Oracle Database 21c that improve the performance of JSON applications and allow the contents of the IM column store to be automatically managed.
# 4  This workshop provides the process of moving an existing WebLogic Server application into a Kubernetes cluster on Oracle Cloud Infrastructure in the Oracle Public Cloud.

# %%
tf
# Out:
# <525x1778 sparse matrix of type '<class 'numpy.int64'>'
# 	with 17287 stored elements in Compressed Sparse Row format>

# %% [markdown]
# **Term Frequencies 살펴보기**
#
# 표제어화된(Lemmatized) 카운트 벡터라이저를 구현한 후 상위 50개 단어(빈도 기준)의 용어 빈도에 대한 도표를 다시 살펴보겠습니다.

# %%
feature_names = tf_vectorizer.get_feature_names()
count_vec = np.asarray(tf.sum(axis=0)).ravel()

# %%
count_vec
# Out:
# array([5, 2, 4, ..., 2, 9, 8])

# %%
zipped = list(zip(feature_names, count_vec))
x, y = (list(x) for x in zip(*sorted(zipped, key=lambda x: x[1], reverse=True)))

# %%
x, y

# %%
# Plotly imports

import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.16.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# 상위 50개 단어 빈도에 대한 Plot.ly 플롯 그리기

data = [go.Bar(
            x = x[0:50],
            y = y[0:50],
            marker= dict(colorscale='Jet',
                         color = y[0:50]
                        ),
            text='Word counts'
    )]

layout = go.Layout(
    title='상위 50개 단어 빈도'
)

fig = go.Figure(data=data, layout=layout)

py.iplot(fig, filename='basic-bar')

# %%
# 하위 50개 단어 빈도에 대한 Plot.ly 플롯 그리기

data = [go.Bar(
            x = x[-100:],
            y = y[-100:],
            marker= dict(colorscale='Portland',
                         color = y[-100:]
                        ),
            text='Word counts'
    )]

layout = go.Layout(
    title='하위 50개 단어 빈도'
)

fig = go.Figure(data=data, layout=layout)

py.iplot(fig, filename='basic-bar')

# %% [markdown]
# ## 3b. Latent Dirichlet Allocation
#
# 이 장에서는 '토픽 모델링'을 통해 모델을 구현합니다. 사용할 알고리즘은 [Latent Dirichlet Allocation](http://scikit-learn.org/stable/modules/generated/sklearn.decomposition.LatentDirichletAllocation.html)입니다.
#
# 토픽 모델링은 문서들에 잠재되어 있는 공통된 토픽(주제)들을 추출해 내는 기법을 의미합니다. 공통된 유사성을 도출한다는 측면에서 Clustering과 비슷한 기법일 수 있지만 토픽 모델링은 1) 문서들이 가지는 주요 토픽의 분포도와 2) 개별 토픽이 이루는 단어들의 분포를 제공한다는 특징을 가지고 있습니다.

# %% [markdown]
# 예를 들어 아래와 같은 문서(Documents)가 있을 때 이 문서의 토픽이 스포츠 주제일 수도 있고 정치 주제일 수도 있습니다. 이런 식으로 한가지 문서가 여러 가지 토픽을 가질 수 있는 것입니다.

# %%
from IPython import display
display.Image("https://blogfiles.pstatic.net/MjAyMjEyMTJfMjYx/MDAxNjcwODQzODA5Mzg4.62Kw5VnRZRMptjF9VMTc8UVYAWd3ox7HTFtG1aySQEYg.3JcZPKcDn7xxGP4HsZF-IKYVpfRpX_ejUX7yKwfD3HYg.PNG.dncks1107/%EB%8B%A4%EC%9A%B4%EB%A1%9C%EB%93%9C.png")

# %% [markdown]
# 아래와 같이 5개의 문서들이 있을 때 100% Topic A로 구성될 수도 있고 60% Topic A 와 40% Topic B가 혼합돼서 구성될 수도 있습니다. 그리고 각 개별 토픽 중 Topic A가 40% banana, 30% kale, 10% breakfast로 구성 되어 있으면 Topic A는 food에 가까울 것이다라고 판별할 수 있습니다.

# %%
display.Image("https://blogfiles.pstatic.net/MjAyMjEyMTJfMjMw/MDAxNjcwODQzODI2MDIz.pRl9SyDe55PqQ4P7otbHwUros7SJX8EVLHjP9comrjwg.1pAkt3U6YrcFU_2sQbhr8XrWVeJB6BjPbddyHWl3Iq8g.PNG.dncks1107/%EB%8B%A4%EC%9A%B4%EB%A1%9C%EB%93%9C_(1).png")

# %%
display.Image("https://blogfiles.pstatic.net/MjAyMjEyMTJfMjEx/MDAxNjcwODQzODMzMzQ4.7s-1u5lQmh7ww_Hkk2RNFT5R2tSVY_0ycuiheT3N2uYg.OA-IzWQfHPoMz5sVyuMzIjrOMPSjRjbX_LcxYzVfhQIg.PNG.dncks1107/%EB%8B%A4%EC%9A%B4%EB%A1%9C%EB%93%9C_(2).png")

# %% [markdown]
# 알고리즘을 호출하기 위해 Sklearn의 *LatentDirichletAllocation* 기능을 통해 LDA 인스턴스를 생성하기만 하면 됩니다. 다양한 매개변수의 값은 default로 몇가지 설정합니다.

# %%
from sklearn.decomposition import LatentDirichletAllocation

lda = LatentDirichletAllocation(n_components=15, max_iter=10,
                                learning_method = 'online',
                                learning_offset = 10.,
                                random_state = 0)
lda.fit(tf)
# Out:
# LatentDirichletAllocation(learning_method='online', n_components=15,
#                           random_state=0)

# %% [markdown]
# ### LDA에서 생성된 주제
#
# "print_top_words" 헬퍼 함수를 활용하여 각 LDA 생성 주제에 귀속된 상위 40개 단어를 반환합니다. 주제 수를 선택하려면 함수의 n_components 매개변수를 통해 처리합니다.

# %%
# top words를 출력하는 헬퍼 함수 정의

n_top_words = 30
tf_feature_names = tf_vectorizer.get_feature_names()

def print_top_words(model, feature_names, n_top_words):
    for index, topic in enumerate(model.components_):
        message = "\nTopic #{}:".format(index)
        message += " ".join([feature_names[i] for i in topic.argsort()[:-n_top_words - 1 :-1]])
        print(message)
        print("="*70)
        
print("\nTopics in LDA model: ")

print_top_words(lda, tf_feature_names, n_top_words)
# Out:
# Topics in LDA model:
#
# Topic #0:hpc function infrastructure oracle compute application workload cloud performance software run capacity issue provides cost needed learning computing faster build like instance enabling engineering saving avoid utilization intensive high innovate
# ======================================================================
#
# Topic #1:document json relational developer view partitioning table duality database oracle feature file partition access building data automatic flexibility benefit 23c apps simplicity auto information department challenge overcomes breakthrough faced historical
# ======================================================================
#
# Topic #2:database oracle cloud service management oci security lab workshop infrastructure using application performance access use solution data workload help user including enterprise identity provides governance premise instance learn experience step
# ======================================================================
#
# Topic #3:application oracle cloud workshop create oci data using user learn database service lab end step use infrastructure app kubernetes process web environment walk set instance cluster developer access deploy resource
# ======================================================================
#
# Topic #4:cloud oracle recovery infrastructure dr oci service stack disaster provide vcn guard compute core certification understanding lab foundation active cover skill perform virtual network storage foundational knowledge automate region workshop
# ======================================================================
#
# Topic #5:model ai image helidon machine learning data microservices using feature service ml ll java oracle oci patient microservice detection type lung use health identify medical healthcare tool new session accelerate
# ======================================================================
#
# Topic #6:oracle movie data integration application search workshop use lab create rest nosql apex user event customer developer cloud using detail watchlist page erp development build video flow business real table
# ======================================================================
#
# Topic #7:patching upgrade fleet maintenance configuration system enterprise end including automate enables database wide range operation different ability dba framework glass pane single benefit listener like varying essbase number condition suspend
# ======================================================================
#
# Topic #8:data oracle database using analytics autonomous object sql workshop use storage stored graph learn table rest insight analysis business adb adw ll query analyze capability source feature language python service
# ======================================================================
#
# Topic #9:object create service request use example storage work authenticated satisfy bucket link play loom routing hour prevent updating extension understand practice later 21c following increased topic oac dba prepare want
# ======================================================================
#
# Topic #10:encryption network improve linking soa adding manipulating usability item client breach motion common minute standard configuration requiring completion early phase parameter form supported native packaged change included good edition cli
# ======================================================================
#
# Topic #11:content record block volume compute agreement message topic instance memory notification dbsat column format store enables row auditing category improve channel schedule delivery workflow deleted subscription order traditional second specific
# ======================================================================
#
# Topic #12:log logging resource atom infrastructure hcm private ingest tenancy public information occurred analyze ingested route software console operational check cost condition accessed report pane human glass change ip search accurate
# ======================================================================
#
# Topic #13:learning machine mysql heatwave notebook oml model using algorithm database application workshop stream oracle spark support insurance autonomous exploration preparation shell analytical run query provides based dashboard leverage python score
# ======================================================================
#
# Topic #14:micro member engineer monolithic reality ask journey fictitious staff java employee converting generation problem role going highlight follow come transform leveraging registry information different organization oracle service cloud processing transaction
# ======================================================================

# %% [markdown]
# ### 주제의 Word Cloud 시각화

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
from wordcloud import WordCloud, STOPWORDS

first_topic = lda.components_[13]
print(first_topic.shape)
print(first_topic)
# Out:
# (1778,)
# [0.07259906 0.07407532 0.07296986 ... 1.50884547 0.07196094 0.07383224]

# %%
first_topic_words = [tf_feature_names[i] for i in first_topic.argsort()[:-50 - 1 :-1]]
firstcloud = WordCloud(   stopwords=STOPWORDS,
                          background_color='black',
                          width=2500,
                          height=1800
                         ).generate(" ".join(first_topic_words))
plt.imshow(firstcloud)
plt.axis('off')
plt.show()

# %%
# 토픽별 문서의 단어 분포

doc_topics=lda.transform(tf)
print(doc_topics.shape)
print(doc_topics[:5])
# Out:
# (525, 15)
# [[0.00121212 0.00121212 0.34229783 0.00121212 0.06691668 0.00121212
#   0.00121212 0.00121212 0.57624002 0.00121212 0.00121212 0.00121213
#   0.00121212 0.00121212 0.00121212]
#  [0.00229885 0.00229885 0.00229886 0.00229886 0.00229886 0.00229886
#   0.96781604 0.00229885 0.00229886 0.00229885 0.00229885 0.00229885
#   0.00229885 0.00229885 0.00229885]
#  [0.00229885 0.00229885 0.36851619 0.00229886 0.00229886 0.00229885
#   0.00229886 0.00229885 0.00229886 0.00229885 0.00229885 0.00229885
#   0.00229885 0.60159872 0.00229885]
#  [0.0010582  0.00105821 0.43151526 0.0010582  0.0010582  0.0010582
#   0.0010582  0.0010582  0.0010582  0.0010582  0.0010582  0.5547281
#   0.0010582  0.0010582  0.0010582 ]
#  [0.00392157 0.00392157 0.00392158 0.94509799 0.00392158 0.00392157
#   0.00392157 0.00392157 0.00392157 0.00392157 0.00392157 0.00392157
#   0.00392158 0.00392157 0.00392157]]

# %% [markdown]
# 총 525개의 행과 15개의 열로 구성되어 있는 array입니다. 여기서 행은 '각 문서들', 열은 '각 토픽들'을 의미합니다. 각 문서들이 실제 무슨 내용으로 구성되어 있는지 살펴봅니다.

# %%
#토픽별 단어들의 분포

print(lda.components_.shape)
print(lda.components_)
# Out:
# (15, 1778)
# [[0.074728   0.07367257 0.07481192 ... 0.07262084 0.07559253 0.07314912]
#  [0.07312279 0.07504677 0.07457638 ... 0.07428988 0.07428126 0.07281941]
#  [4.08742882 0.81022146 1.48536801 ... 0.20965799 7.61211302 0.08304189]
#  ...
#  [0.07338457 0.07420945 0.07272537 ... 0.07358944 0.07336058 0.07320358]
#  [0.07259906 0.07407532 0.07296986 ... 1.50884547 0.07196094 0.07383224]
#  [0.07221606 0.07372841 0.07361333 ... 0.07287839 0.07343029 0.07304359]]

# %% [markdown]
# shape으로 15개의 행, 1778개의 칼럼으로 이루어진 array를 반환합니다. 여기서 행은 각각의 Topic, 열은 단어를 벡터화시킨 Feature들입니다. 이제 토픽별로 어떤 단어들이 많이 분포하는지 시각적으로 보기 편하게 하도록 함수 하나를 개별적으로 정의합니다.

# %%
topic_index=list(df_final3.index.values)

topic_names = ['Topic #'+str(i) for i in range(0,15)]
topic_df = pd.DataFrame(data=doc_topics, columns=topic_names, index=topic_index)
topic_df.head()
# Out:
#    Topic #0  Topic #1  Topic #2  Topic #3  Topic #4  Topic #5  Topic #6  Topic #7  Topic #8  Topic #9  Topic #10  Topic #11  Topic #12  Topic #13  Topic #14
# 0  0.001212  0.001212  0.342298  0.001212  0.066917  0.001212  0.001212  0.001212  0.576240  0.001212  0.001212   0.001212   0.001212   0.001212   0.001212
# 1  0.002299  0.002299  0.002299  0.002299  0.002299  0.002299  0.967816  0.002299  0.002299  0.002299  0.002299   0.002299   0.002299   0.002299   0.002299
# 2  0.002299  0.002299  0.368516  0.002299  0.002299  0.002299  0.002299  0.002299  0.002299  0.002299  0.002299   0.002299   0.002299   0.601599   0.002299
# 3  0.001058  0.001058  0.431515  0.001058  0.001058  0.001058  0.001058  0.001058  0.001058  0.001058  0.001058   0.554728   0.001058   0.001058   0.001058
# 4  0.003922  0.003922  0.003922  0.945098  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922   0.003922   0.003922   0.003922   0.003922

# %% [markdown]
# 문서를 특정 주제로 분리시키기 위해서는 해당 문서에 가장 많이 확인되는 Topic을 확인하고 할당하는 것입니다. 아래 테이블에서 문서의 모든 주요 주제를 녹색으로 표시하고 자체 열에 가장 지배적인 주제를 할당했습니다.

# %%
# 각 문서에 대한 주요 topic 가져오기

dominant_topic = np.argmax(topic_df.values, axis=1)
topic_df['dominant_topic'] = dominant_topic

# Styling

def color_green(val):
 color = 'green' if val > .1 else 'black'
 return 'color : {col}'.format(col=color)

def make_bold(val):
 weight = 700 if val > .1 else 400
 return 'font-weight: {weight}'.format(weight=weight)

# Apply Style

df_document_topics = topic_df.head(15).style.applymap(color_green).applymap(make_bold)
df_document_topics
# Out:
# <style type="text/css">
# #T_6c4b1_row0_col0, #T_6c4b1_row0_col1, #T_6c4b1_row0_col3, #T_6c4b1_row0_col4, #T_6c4b1_row0_col5, #T_6c4b1_row0_col6, #T_6c4b1_row0_col7, #T_6c4b1_row0_col9, #T_6c4b1_row0_col10, #T_6c4b1_row0_col11, #T_6c4b1_row0_col12, #T_6c4b1_row0_col13, #T_6c4b1_row0_col14, #T_6c4b1_row1_col0, #T_6c4b1_row1_col1, #T_6c4b1_row1_col2, #T_6c4b1_row1_col3, #T_6c4b1_row1_col4, #T_6c4b1_row1_col5, #T_6c4b1_row1_col7, #T_6c4b1_row1_col8, #T_6c4b1_row1_col9, #T_6c4b1_row1_col10, #T_6c4b1_row1_col11, #T_6c4b1_row1_col12, #T_6c4b1_row1_col13, #T_6c4b1_row1_col14, #T_6c4b1_row2_col0, #T_6c4b1_row2_col1, #T_6c4b1_row2_col3, #T_6c4b1_row2_col4, #T_6c4b1_row2_col5, #T_6c4b1_row2_col
, #T_6c4b1_row10_col3, #T_6c4b1_row10_col4, #T_6c4b1_row10_col5, #T_6c4b1_row10_col7, #T_6c4b1_row10_col8, #T_6c4b1_row10_col9, #T_6c4b1_row10_col10, #T_6c4b1_row10_col11, #T_6c4b1_row10_col12, #T_6c4b1_row10_col13, #T_6c4b1_row10_col14, #T_6c4b1_row11_col0, #T_6c4b1_row11_col1, #T_6c4b1_row11_col2, #T_6c4b1_row11_col4, #T_6c4b1_row11_col5, #T_6c4b1_row11_col6, #T_6c4b1_row11_col7, #T_6c4b1_row11_col9, #T_6c4b1_row11_col10, #T_6c4b1_row11_col11, #T_6c4b1_row11_col12, #T_6c4b1_row11_col14, #T_6c4b1_row12_col0, #T_6c4b1_row12_col1, #T_6c4b1_row12_col2, #T_6c4b1_row12_col4, #T_6c4b1_row12_col6, #T_6c4b1_row12_col7, #T_6c4b1_row12_col8, #T_6c4b1_row12_col9, #T_6c4b1_row12_col10, #T_6c4b1_row12_col11, #T_6c4b1_row12_col12, #T_6c4b1_row12_col13, #T_6c4b1_row12_col14, #T_6c4b1_row13_col0, #T_6c4b1_row13_col1, #T_6c4b1_row13_col2, #T_6c4b1_row13_col4, #T_6c4b1_row13_col5, #T_6c4b1_row13_col6, #T_6c4b1_row13_col7, #T_6c4b1_row13_col9, #T_6c4b1_row13_col10, #T_6c4b1_row13_col11, #T_6c4b1_row13_col12, #T_6c4b1_row13_col13, #T_6c4b1_row13_col14, #T_6c4b1_row14_col1, #T_6c4b1_row14_col2, #T_6c4b1_row14_col4, #T_6c4b1_row14_col5, #T_6c4b1_row14_col6, #T_6c4b1_row14_col7, #T_6c4b1_row14_col8, #T_6c4b1_row14_col9, #T_6c4b1_row14_col10, #T_6c4b1_row1 ...
#   color: black;
#   font-weight: 400;
# }
# #T_6c4b1_row0_col2, #T_6c4b1_row0_col8, #T_6c4b1_row0_col15, #T_6c4b1_row1_col6, #T_6c4b1_row1_col15, #T_6c4b1_row2_col2, #T_6c4b1_row2_col13, #T_6c4b1_row2_col15, #T_6c4b1_row3_col2, #T_6c4b1_row3_col11, #T_6c4b1_row3_col15, #T_6c4b1_row4_col3, #T_6c4b1_row4_col15, #T_6c4b1_row5_col1, #T_6c4b1_row5_col8, #T_6c4b1_row5_col15, #T_6c4b1_row6_col2, #T_6c4b1_row6_col15, #T_6c4b1_row7_col3, #T_6c4b1_row7_col13, #T_6c4b1_row7_col15, #T_6c4b1_row8_col2, #T_6c4b1_row8_col4, #T_6c4b1_row8_col15, #T_6c4b1_row9_col3, #T_6c4b1_row9_col8, #T_6c4b1_row9_col15, #T_6c4b1_row10_col2, #T_6c4b1_row10_col6, #T_6c4b1_row10_col15, #T_6c4b1_row11_col3, #T_6c4b1_row11_col8, #T_6c4b1_row11_col13, #T_6c4b1_row11_col15, #T_6c4b1_row12_col3, #T_6c4b1_row12_col5, #T_6c4b1_row12_col15, #T_6c4b1_row13_col3, #T_6c4b1_row13_col8, #T_6c4b1_row13_col15, #T_6c4b1_row14_col0, #T_6c4b1_row14_col3, #T_6c4b1_row14_col15 {
#   color: green;
#   font-weight: 700;
# }
# </style>
# <table id="T_6c4b1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c4b1_level0_col0" class="col_heading level0 col0" >Topic #0</th>
#       <th id="T_6c4b1_level0_col1" class="col_heading level0 col1" >Topic #1</th>
#       <th id="T_6c4b1_level0_col2" class="col_heading level0 col2" >Topic #2</th>
#       <th id="T_6c4b1_level0_col3" class="col_heading level0 col3" >Topic #3</th>
#       <th id="T_6c4b1_level0_col4" class="col_heading level0 col4" >Topic #4</th>
#       <th id="T_6c4b1_level0_col5" class="col_heading level0 col5" >Topic #5</th>
#       <th id="T_6c4b1_level0_col6" class="col_heading level0 col6" >Topic #6</th>
#       <th id="T_6c4b1_level0_col7" class="col_heading level0 col7" >Topic #7</th>
#       <th id="T_6c4b1_level0_col8" class="col_heading level0 col8" >Topic #8</th>
#       <th id="T_6c4b1_level0_col9" class="col_heading level0 col9" >Topic #9</th>
#       <th id="T_6c4b1_level0_col10" class="col_heading level0 col10" >Topic #10</th>
#       <th id="T_6c4b1_level0_col11" class="col_heading level0 col11" >Topic #11</th>
#       <th id="T_6c4b1_level0_col12" class="col_heading level0 col12" >Topic #12</th>
#       <th id="T_6c4b1_level0_col13" class="col_heading level0 col13" >Topic #13</th>
#       <th id="T_6c4b1_level0_col14" class="col_heading level0 col14" >Topic #14</th>
#       <th id="T_6c4b1_level0_col15" class="col_heading level0 col15" >dominant_topic</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c4b1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6c4b1_row0_col0" class="data row0 col0" >0.001212</td>
#       <td id="T_6c4b1_row0_col1" class="data row0 col1" >0.001212</td>
#       <td id="T_6c4b1_row0_col2" class="data row0 col2" >0.342298</td>
#       <td id="T_6c4b1_row0_col3" class="data row0 col3" >0.001212</td>
#       <td id="T_6c4b1_row0_col4" class="data row0 col4" >0.066917</td>
#       <td id="T_6c4b1_row0_col5" class="data row0 col5" >0.001212</td>
#       <td id="T_6c4b1_row0_col6" class="data row0 col6" >0.001212</td>
#       <td id="T_6c4b1_row0_col7" class="data row0 col7" >0.001212</td>
#       <td id="T_6c4b1_row0_col8" class="data row0 col8" >0.576240</td>
#       <td id="T_6c4b1_row0_col9" class="data row0 col9" >0.001212</td>
#       <td id="T_6c4b1_row0_col10" class="data row0 col10" >0.001212</td>
#       <td id="T_6c4b1_row0_col11" class="data row0 col11" >0.001212</td>
#       <td id="T_6c4b1_row0_col12" class="data row0 col12" >0.001212</td>
#       <td id="T_6c4b1_row0_col13" class="data row0 col13" >0.001212</td>
#       <td id="T_6c4b1_row0_col14" class="data row0 col14" >0.001212</td>
#       <td id="T_6c4b1_row0_col15" class="data row0 col15" >8</td>
#     </tr>
#     <tr>
#       <th id="T_6c4b1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6c4b1_row1_col0" class="data row1 col0" >0.002299</td>
#       <td id="T_6c4b1_row1_col1" class="data row1 col1" >0.002299</td>
#       <t

# %%
df_document_topics = topic_df.style.applymap(color_green).applymap(make_bold)
topic_data = df_document_topics.data
type(topic_data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# 위 구현된 lda 모델을 사용해서 sample 문구를 입력하여 sample 문구에 해당되는 Topic을 할당해보겠습니다.

# %%
sample = ["I want to learn MACHINE LEARNING on HEATWAVE"]

# %%
sample_vec = tf_vectorizer.transform(sample)

# %%
topic_probability_scores = lda.transform(sample_vec)

# %%
topic_probability_scores
# Out:
# array([[0.01111111, 0.01111111, 0.01111113, 0.19561918, 0.01111114,
#         0.01111112, 0.01111113, 0.01111111, 0.01111114, 0.01111111,
#         0.01111111, 0.01111111, 0.01111111, 0.65993626, 0.01111111]])

# %%
topic_chosen = np.argmax(topic_probability_scores)
print(topic_chosen)
# Out:
# 13

# %%
first_topic_words = [tf_feature_names[i] for i in first_topic.argsort()[:-50 - 1 :-1]]
firstcloud = WordCloud(   stopwords=STOPWORDS,
                          background_color='black',
                          width=2500,
                          height=1800
                         ).generate(" ".join(first_topic_words))
plt.imshow(firstcloud)
plt.axis('off')
plt.show()

# %%
topic_data.loc[topic_data['dominant_topic']==topic_chosen]
# Out:
#      Topic #0  Topic #1  Topic #2  Topic #3  Topic #4  Topic #5  Topic #6  Topic #7  Topic #8  Topic #9  Topic #10  Topic #11  Topic #12  Topic #13  Topic #14  dominant_topic
# 2    0.002299  0.002299  0.368516  0.002299  0.002299  0.002299  0.002299  0.002299  0.002299  0.002299  0.002299   0.002299   0.002299   0.601599   0.002299   13
# 7    0.002083  0.002083  0.002083  0.363517  0.002083  0.002083  0.002083  0.002083  0.002083  0.002083  0.002083   0.002083   0.002083   0.609400   0.002083   13
# 11   0.001626  0.001626  0.001626  0.341659  0.001626  0.001626  0.001626  0.001626  0.129760  0.001626  0.001626   0.001626   0.001626   0.509068   0.001626   13
# 154  0.001418  0.001418  0.001418  0.001418  0.001418  0.001418  0.293696  0.001418  0.001418  0.001418  0.001418   0.001418   0.001418   0.687864   0.001418   13
# 161  0.003704  0.003704  0.003704  0.003704  0.003704  0.003704  0.003704  0.003704  0.003704  0.003704  0.003704   0.003704   0.003704   0.948148   0.003704   13
# 218  0.006061  0.006061  0.323253  0.006061  0.006061  0.006061  0.006061  0.006061  0.006061  0.006061  0.006061   0.006061   0.006061   0.597959   0.006061   13
# 237  0.001190  0.001190  0.337713  0.208356  0.001190  0.001190  0.001190  0.001190  0.001190  0.001190  0.001190   0.001190   0.001190   0.439645   0.001190   13
# 244  0.001258  0.001258  0.152340  0.150850  0.001258  0.001258  0.001258  0.001258  0.206025  0.001258  0.001258   0.001258   0.001258   0.476948   0.001258   13
# 254  0.008333  0.008333  0.008333  0.008333  0.008333  0.008333  0.008333  0.008333  0.386842  0.008333  0.008333   0.008333   0.008333   0.504825   0.008333   13
# 461  0.000694  0.000694  0.174230  0.249223  0.000694  0.000694  0.000694  0.000694  0.224152  0.000694  0.000694   0.000694   0.000694   0.344755   0.000694   13
# 465  0.000866  0.000866  0.166722  0.000866  0.000866  0.200782  0.114156  0.000866  0.151687  0.000866  0.000866   0.000866   0.000866   0.357995   0.000866   13
# 548  0.002083  0.002083  0.002083  0.339668  0.002083  0.084645  0.002083  0.002083  0.002083  0.002083  0.002083   0.002083   0.002083   0.550687   0.002083   13
# 580  0.005556  0.005556  0.005556  0.005556  0.005556  0.005556  0.295626  0.005556  0.005556  0.005556  0.005556   0.005556   0.005556   0.632151   0.005556   13
# 584  0.165679  0.002778  0.002778  0.002778  0.002778  0.071823  0.002778  0.002778  0.250599  0.002778  0.002778   0.002778   0.044444   0.439677   0.002778   13

# %%
indices = topic_data.index[topic_data['dominant_topic'] == topic_chosen]
print(indices)

for index in indices:
    print(crawled_parquet_df.loc[index])
    print(   )
# Out:
# Int64Index([2, 7, 11, 154, 161, 218, 237, 244, 254, 461, 465, 548, 580, 584], dtype='int64')
# ID                560
# TITLE             Machine Learning on Autonomous Database
# URL               https://apexapps.oracle.com/pls/apex/r/dbpm/livelabs/run-workshop?p210_wid=560
# TYPE              Hands-on
# DESCRIPTION       Oracle integrates machine learning across the Oracle stack and the enterprise, fully leveraging Oracle Database and Oracle Autonomous Database.  In this workshop, create a machine learning model and move the model to ADB.  Explore machine learning notebooks and use prediction in applications.
# DURATION          2 hours
# PUBLISHED_TIME    2017-09-04T05:55:07
# TITLE_KO          Autonomous Database의 머신 러닝
# DESC_KO           Oracle은 Oracle Database와 Oracle Autonomous Database를 완전히 활용하여 Oracle 스택과 기업 전반에 머신 러닝을 통합합니다. 이 워크샵에서는 머신 러닝 모델을 생성하고 모델을 ADB로 이동합니다. 머신 러닝 노트북을 살펴보고 애플리케이션에서 예측 기능을 사용합니다.
# DURATION_KO       2시간
# OCI_PRODUCTS      adb,machine learning notebooks,applications
# KEY_PHRASE        machine learning,autonomous databaseoracle integrates machine,oracle stack,leveraging oracle database,oracle autonomous database,machine learning model,explore machine learning notebooks,enterprise,adb,prediction
# Name: 2, dtype: object
#
# ID                577
# TITLE             Oracle's Cloud Data Platform: Autonomous-Driven & AI-Infused
# URL               https://apexapps.oracle.com/pls/apex/r/dbpm/livelabs/run-workshop?p210_wid=577
# TYPE              Hands-on
# DESCRIPTION       This workshop will walk you through the process of using the Autonomous Data Warehouse for storing analytical datasets and applying Machine Learning models in order to learn the correlation between different attributes and predict the future demand while leveraging Application Express to create a simple application as well as link to a 3rd party web app.
# DURATION          3 hours
# PUBLISHED_TIME    2017-09-14T06:42:57
# TITLE_KO          Oracle의 클라우드 데이터 플랫폼: 자율 기반 및 AI 기반
# DESC_KO           이 워크샵에서는 Autonomous Data Warehouse를 사용하여 분석 데이터 세트를 저장하고 머신 러닝 모델을 적용하는 과정을 안내하여 서로 다른 속성 간의 상관 관계를 학습하고 Application Express를 활용하여 간단한 애플리케이션을 생성하고 타사 웹 앱에 대한 링크를 통해 미래 수요를 예측할 수 있습니다.
# DURATION_KO       3시간
# OCI_PRODUCTS      web app
# KEY_PHRASE        oracle's cloud data platform,autonomous data warehouse,analytical datasets,applying machine learning models,different attributes,future demand,leveraging application express,simple application,3rd party web app,correlation
# Name: 7, dtype: object
#
# ID                586
# TITLE             Introduction to Machine Learning Algorithms on ADB
# URL               https://apexapps.oracle.com/pls/apex/r/dbpm/livelabs/run-workshop?p210_wid=586
# TYPE              Hands-on
# DESCRIPTION       In this workshop you will explore the Oracle Machine Learning (OML) SQL notebook application provided with your Autonomous Data Warehouse. This browser-based application provides a web interface to run SQL queries and scripts, which can be grouped together within a notebook. Notebooks can be used to build single reports, collections of reports, and even dashboards. OML provides a simple way to share workbooks, and collections of workbooks, with other OML users.
# DURATION          45 minutes
# PUBLISHED_TIME    2017-09-16T21:09:56
# TITLE_KO          ADB의 머신 러닝 알고리즘 소개
# DESC_KO           이 워크샵에서는 Autonomous Data Warehouse와 함께 제공되는 OML(Oracle Machine Learning) SQL 노트북 애플리케이션을 살펴봅니다. 이 브라우저 기반 응용 프로그램은 노트북 내에서 함께 그룹화할 수 있는 SQL 질의 및 스크립트를 실행하기 위한 웹 인터페이스를 제공합니다. 노트북은 단일 보고서, 보고서 모음 및 대시보드(Dashboard)를 작성하는 데 사용할 수 있습니다. OML은 다른 OML 사용자와 워크북 및 워크북 모음을 공유하는 간단한 방법을 제공합니다.
# DURATION_KO       45분후
# OCI_PRODUCTS      notebook,dashboards,sql,notebooks,workbooks
# KEY_PHRASE        oml,machine learning algorithms,oracle machine learning,sql notebook application,autonomous data warehouse,browser-based application,web interface,queries and scripts,single reports,collections of reports
# Name: 11, dtype: object
#
# ID                782
# TITLE             Predicting Auto Claim Fraud with Oracle Machine Learning
# URL               https://apexapps.oracle.com/pls/apex/r/dbpm/livelabs/run-workshop?p210_wid=782
# TYPE              Hands-on
# DESCRIPTION       Automotive insurance fraud involves someone deceiving an insurance company about a claim involving their personal or commercial motor vehicle. It can involve giving out misleading information or providing false documentation to support the claim. This workshop highlights the use of two Oracle Machine Learning notebooks working in conjunction with automobile insurance claims investigators in a two-step process. First, we use Oracle Machine Learning to “flag” for the investigator anomalous insurance claims using an unsupervised learning algorithm (1-Class Support Vector Machine). We help the claims investigators focus on the most suspicious claims using their expertise and knowledge using an Oracle APEX application.
# DURATION          1 hour
# PUBLISHED_TIME    2018-09-26T19:43:14
# TITLE_KO          Oracle Machine Learning으로 자동 청구 사기 예측
# DESC_KO           자동차 보험 사기에는 개인 또는 상업용 자동차와 관련된 청구에 대해 보험 회사를 속이는 사람이 포함됩니다. 여기에는 잘못된 정보를 제공하거나 청구를 지원하기 위해 잘못된 문서를 제공하는 작업이 포함될 수 있습니다. 이 워크숍에서는 2단계 프로세스에서 자동차 보험 청구 조사관과 함께 작동하는 2개의 Oracle Machine Learning 노트북 사용을 집중적으로 다룹니다. 첫째, Oracle Machine Learning을 사용하여 비지도 학습 알고리즘(1등급 Support Vector Machine)을 사용하여 조사관 비정상적인 보험 청구에 대해 "플래그"합니다. 청구 조사자는 Oracle APEX 애플리케이션을 사용하여 전문 지식과 지식을 사용하여 가장 의심스러운 청구에 집중할 수 있습니다.
# DURATION_KO       1시간
# OCI_PRODUCTS      automobile insurance,commercial motor vehicle,auto,insurance
# KEY_PHRASE        predicting auto claim fraud,insurance company,misleading information,false documentation,automobile insurance claims investigators,two-step process,oracle machine learning,investigator anomalous insurance claims,unsupervised learning algorithm,1-class support vector machine
# Name: 154, dtype: object
#
# ID                795
# TITLE             Configuring Private DNS ..
# URL               https://apexapps.oracle.com/pls/apex/r/dbpm/livelabs/run-workshop?p210_wid=795
# TYPE              Hands-on
# DESCRIPTION       Customers want to specify their own private DNS domain names to manage their private assets in OCI as well as support DNS resolution between VCNs and between VCNs and on-premise networks.
# DURATION          30 minutes
# PUBLISHED_TIME    2018-10-12T23:10:04
# TITLE_KO          전용 DNS 구성 중...
# DESC_KO           고객은 자신의 전용 DNS 도메인 이름을 지정하여 OCI에서 전용 자산을 관리하고 VCN과 VCN, 온프레미스 네트워크 간의 DNS 확인을 지원하고자 합니다.
# DURATION_KO       30분
# OCI_PRODUCTS      vcns,dns
# KEY_PHRASE        private dns,private assets,support dns resolution,vcns and on-premise networks,customers,vcns,oci
# Name: 161, dtype: object
#
# ID                861
# TITLE             Machine Learning on ADB – Choose your Journey
# URL               https://apexapps.oracle.com/pls/apex/r/dbpm/livelabs/run-workshop?p210_wid=861
# TYPE              Hands-on
# DESCRIPTION       In this workshop, you will explore Oracle machine learning by choosing your learning path - either on Autonomous Database or for Python.
# DURATION          2 hours
# PUBLISHED_TIME    2019-02-28T04:52:47
# TITLE_KO          ADB에서의 머신 러닝 - 여정 선택
# DESC_KO           이 워크샵에서는 Autonomous Database 또는 Python에서 학습 경로를 선택하여 Oracle 머신 러닝을 살펴봅니다.
# DURATION_KO       2시간
# OCI_PRODUCTS      python
# KEY_PHRASE        machine learning,oracle machine,learning path,autonomous database,journeyin,python
# Name: 218, dtype: object
#
# ID                882
# TITLE             Get started with MySQL HeatWave to turbocharge business insights
# URL               https://apexapps.oracle.com/pls/apex/r/dbpm/livelabs/run-workshop?p210_wid=882
# TYPE              Hands-on
# DESCRIPTION       In this workshop you will learn how to get started with MySQL HeatWave on Oracle Cloud Infrastructure (OCI). You will learn how to create a MySQL HeatWave instance, connect to the cluster using MySQL Shell and OCI Cloud Shell, and run queries, analytic workloads, and machine learning applications with HeatWave. You will experience for yourself how MySQL HeatWave’s massively parallel, in-memory query accelerator with machine learning-powered automation can accelerate your database applications by orders of magnitude, enabling you to make informed business critical decisions with real-time insights.
# DURATION          4 hours
# PUBLISHED_TIME    2019-04-08T18:47:09
# TITLE_KO          MySQL HeatWave로 시작하여 비즈니스 통찰력 강화
# DESC_KO           이 워크숍에서는 OCI(Oracle Cloud Infrastructure)에서 MySQL HeatWave를 시작하는 방법을 알아봅니다. MySQL HeatWave 인스턴스를 생성하고 MySQL 셸 및 OCI Cloud Shell을 사용하여 클러스터에 연결하며 HeatWave으로 쿼리, 애널리틱스 워크로드 및 머신 러닝 애플리케이션을 실행하는 방법을 알아봅니다. MySQL 머신 러닝 기반 자동화를 통한 HeatWave의 대규모 병렬 인메모리 쿼리 가속기가 데이터베이스 애플리케이션을 수십 배 가속화하여 실시간 인사이트를 통해 정보에 기반한 중요한 비즈니스 의사 결정을 내릴 수 있는 방법을 직접 경험할 수 있습니다.
# DURATION_KO       4시간
# OCI_PRODUCTS      heatwave,mysql shell,oci cloud shell,turbocharge,oci,machine learning applications
# KEY_PHRASE        mysql heatwave,turbocharge business,oracle cloud infrastructure,mysql heatwave instance,using mysql shell,oci cloud shell,analytic workloads,machine learning applications,mysql heatwave's,in-memory query accelerator
# Name: 237, dtype: object
#
# ID                891
# TITLE             Introduction to Oracle Machine Learning Notebooks
# URL               https://apexapps.oracle.com/pls/apex/r/dbpm/livelabs/run-workshop?p210_wid=891
# TYPE              Hands-on
# DESCRIPTION       Oracle Machine Learning Notebooks is an Apache Zeppelin-based collaborative web-based interface that provides a development environment to create machine learning notebooks where you can perform data exploration and visualizations, data preparation and machine learning. Key features of Oracle Machine Learning Notebook:*  Allows collaboration among data scientists, business and data analysts, application and dashboard developers, Database Administrators, and IT professionals. *  Leverages the scalability and performance of Oracle Platform and its Cloud Services.
# DURATION          45 minutes
# PUBLISHED_TIME    2019-04-23T08:53:51
# TITLE_KO          Oracle Machine Learning Notebooks 소개
# DESC_KO           Oracle Machine Learning Notebooks는 데이터 탐색 및 시각화, 데이터 준비 및 머신 러닝을 수행할 수 있는 머신 러닝 노트북을 만들기 위한 개발 환경을 제공하는 Apache Zeppelin 기반의 협업 웹 기반 인터페이스입니다. Oracle Machine Learning 노트북의 주요 기능:*  데이터 과학자, 비즈니스 및 데이터 분석가, 애플리케이션 및 대시보드 개발자, 데이터베이스 관리자 및 IT 전문가 간의 협업을 허용합니다. *  Oracle Platform 및 클라우드 서비스의 확장성과 성능을 활용합니다.
# DURATION_KO       45분후
# OCI_PRODUCTS      machine learning notebook,machine learning notebooks,machine learning notebooksoracle,cloud services
# KEY_PHRASE        development environment,machine learning notebooks,data exploration and visualizations,key features,oracle machine learning notebook,data scientists,business and data analysts,application and dashboard developers,database administrators,it professionals
# Name: 244, dtype: object
#
# ID                906
# TITLE             OML4Py - Oracle Machine Learning for Python
# URL               https://apexapps.oracle.com/pls/apex/r/dbpm/livelabs/run-workshop?p210_wid=906
# TYPE              Hands-on
# DESCRIPTION       Learn OML4PY - Oracle Database Machine Learning in Python.
# DURATION          4 hours
# PUBLISHED_TIME    2019-05-16T23:47:53
# TITLE_KO          OML4Py - Oracle Machine Learning for Python
# DESC_KO           OML4PY 살펴보기 - Python의 Oracle Database Machine Learning.
# DURATION_KO       4시간
# OCI_PRODUCTS      None
# KEY_PHRASE        oracle machine learning,oml4py,python
# Name: 254, dtype: object
#
# ID                3204
# TITLE             Introduction to Oracle Machine Learning for R on Oracle Database
# URL               https://apexapps.oracle.com/pls/apex/r/dbpm/livelabs/run-workshop?p210_wid=3204
# TYPE              Hands-on
# ...
# DESCRIPTION       With the introduction of Oracle Machine Learning Services with Oracle Autonomous Database, Oracle makes it easy for data science teams and application developers to manage and deploy machine learning models using a REST API, and for ease of application integration. OML Services extends OML functionality to support model deployment and model lifecycle management for both in-database OML models and third-party Open Neural Networks Exchange (ONNX) format machine learning models through REST APIs.In this workshop, we are going to crate, train, deploy and score machine learning models based on customer insurance data using Autonomous Database and tools like AutoML User Interface, and OML Services and REST APIs.
# DURATION          4 hours
# PUBLISHED_TIME    2020-08-14T17:04:11
# TITLE_KO          Oracle Machine Learning Services: REST를 사용한 모델 배포
# DESC_KO           Oracle Autonomous Database의 Oracle Machine Learning Services가 도입됨에 따라 Oracle은 데이터 과학 팀과 애플리케이션 개발자가 REST API를 사용하여 머신 러닝 모델을 쉽게 관리하고 배포할 수 있으며 간편한 애플리케이션 통합이 가능합니다. OML 서비스는 OML 기능을 확장하여 REST를 통해 데이터베이스 내 OML 모델 및 타사 OONNX(Open Neural Networks Exchange) 형식 머신 러닝 모델에 대한 모델 배포 및 모델 라이프사이클 관리를 지원합니다. APIs.In이 워크숍에서는 Autonomous Database와 AutoML 사용자 인터페이스, OML 서비스 및 REST API와 같은 툴을 사용하여 고객 보험 데이터를 기반으로 머신 러닝 모델을 생성, 교육, 배포 및 점수를 매길 수 있습니다.
# DURATION_KO       4시간
# OCI_PRODUCTS      machine learning services,automl,apis,rest api
# KEY_PHRASE        oracle machine learning services,oml services,model deployment,using restwith,oracle autonomous database,machine learning models,rest api,ease of application integration,oml functionality,format machine learning models
# Name: 465, dtype: object
#
# ID                3306
# TITLE             Get started with MySQL HeatWave Machine Learning
# URL               https://apexapps.oracle.com/pls/apex/r/dbpm/livelabs/run-workshop?p210_wid=3306
# TYPE              Hands-on
# DESCRIPTION       In this workshop, users will learn to implement the "Iris Flowers" project with  HeatWave Machine Learning (ML). This project is also known as the Hello World version of Machine Learning. The user will create a HeatWave MySQL database system and build a predictive machine learning model using the Machine Learning capabilities of HeatWave.
# DURATION          2 hours
# PUBLISHED_TIME    2021-03-17T12:28:07
# TITLE_KO          MySQL HeatWave 머신 러닝 시작하기
# DESC_KO           이 워크샵에서는 HeatWave ML(머신 러닝)을 사용하여 "Iris Flowers" 프로젝트를 구현하는 방법을 배웁니다. 이 프로젝트는 Hello World 버전의 머신 러닝이라고도 합니다. 사용자는 HeatWave MySQL 데이터베이스 시스템을 생성하고 HeatWave의 머신 러닝 기능을 사용하여 예측 머신 러닝 모델을 구축합니다.
# DURATION_KO       2시간
# OCI_PRODUCTS      hello world,heatwave,heatwave mysql,heatwave machine learning,machine learning
# KEY_PHRASE        mysql heatwave machine learningin,iris flowers,heatwave machine learning,hello world version,machine learning,heatwave mysql database system,predictive machine learning model,machine learning capabilities,users,ml
# Name: 548, dtype: object
#
# ID                3343
# TITLE             Use OCI Streaming as Managed Kafka server
# URL               https://apexapps.oracle.com/pls/apex/r/dbpm/livelabs/run-workshop?p210_wid=3343
# TYPE              Hands-on
# DESCRIPTION       In this workshop, - you will create a Stream in Oracle Streaming - produce and consume message from it from a Java Kafka client
# DURATION          30 minutes
# PUBLISHED_TIME    2021-05-12T15:28:30
# TITLE_KO          OCI Streaming을 관리형 Kafka 서버로 사용
# DESC_KO           이 워크샵에서는 Oracle Streaming에 Stream을 생성하여 Java Kafka 클라이언트에서 메시지를 생성하고 사용합니다.
# DURATION_KO       30분
# OCI_PRODUCTS      kafka
# KEY_PHRASE        managed kafka,oracle streaming,java kafka client,produce,message,oci
# Name: 580, dtype: object
#
# ID                3347
# TITLE             MySQL Databases: monitoring & troubleshooting using machine learning
# URL               https://apexapps.oracle.com/pls/apex/r/dbpm/livelabs/run-workshop?p210_wid=3347
# TYPE              Hands-on
# DESCRIPTION       It has become increasingly complex to ensure health, troubleshoot issues faster, and continuously monitor. In this workshop learn how to overcome the complexity and identify root cause issues with MySQL databases using Logging Analytics machine learning.
# DURATION          1 hour, 30 minutes
# PUBLISHED_TIME    2021-05-23T10:22:13
# TITLE_KO          MySQL 데이터베이스: 머신 러닝을 사용하여 모니터링 및 문제 해결
# DESC_KO           건강을 보장하고 문제를 더 빠르게 해결하며 지속적으로 모니터링하기 위해 점점 더 복잡해지고 있습니다. 이 워크샵에서는 Logging Analytics 머신 러닝을 사용하여 MySQL 데이터베이스의 복잡성을 극복하고 근본 원인 문제를 식별하는 방법을 배웁니다.
# DURATION_KO       1시간 30분
# OCI_PRODUCTS      machine
# KEY_PHRASE        mysql databases,using machine learningit,troubleshoot issues,root cause issues,complexity
# Name: 584, dtype: object

# %% [markdown]
# ---

# %% [markdown]
# # 4. KMeans Clustering
#
# 이 장에서는 Livelab별 군집을 형성할 것입니다.
#
# 위 **Latent Dirichlet Allocation**에서 각 Topic별 할당된 Probability를 feature로 cluster를 형성합니다. 위 dominant topic과 cluster과의 관계도 비교해봅니다.

# %%
topic_df.head()
# Out:
#    Topic #0  Topic #1  Topic #2  Topic #3  Topic #4  Topic #5  Topic #6  Topic #7  Topic #8  Topic #9  Topic #10  Topic #11  Topic #12  Topic #13  Topic #14  dominant_topic
# 0  0.001212  0.001212  0.342298  0.001212  0.066917  0.001212  0.001212  0.001212  0.576240  0.001212  0.001212   0.001212   0.001212   0.001212   0.001212   8
# 1  0.002299  0.002299  0.002299  0.002299  0.002299  0.002299  0.967816  0.002299  0.002299  0.002299  0.002299   0.002299   0.002299   0.002299   0.002299   6
# 2  0.002299  0.002299  0.368516  0.002299  0.002299  0.002299  0.002299  0.002299  0.002299  0.002299  0.002
0.002667  0.002667   0.002667   0.002667   0.002667   0.002667   3               10
# 797  0.002667  0.002667  0.152539  0.633113  0.002667  0.002667  0.002667  0.182348  0.002667  0.002667  0.002667   0.002667   0.002667   0.002667   0.002667   3               10
# 808  0.002564  0.002564  0.306165  0.660502  0.002564  0.002564  0.002564  0.002564  0.002564  0.002564  0.002564   0.002564   0.002564   0.002564   0.002564   3               10
# 827  0.000595  0.000595  0.233667  0.758594  0.000595  0.000595  0.000595  0.000595  0.000595  0.000595  0.000595   0.000595   0.000595   0.000595   0.000595   3               10
# 842  0.002151  0.002151  0.155893  0.710579  0.107721  0.002151  0.002151  0.002151  0.002151  0.002151  0.002151   0.002151   0.002151   0.002151   0.002151   3               10
# 844  0.002564  0.002564  0.002564  0.671336  0.002564  0.002564  0.002564  0.002564  0.002564  0.002564  0.295330   0.002564   0.002564   0.002564   0.002564   3               10
# 856  0.002564  0.002564  0.002564  0.647640  0.002564  0.319027  0.002564  0.002564  0.002564  0.002564  0.002564   0.002564   0.002564   0.002564   0.002564   3               10

# %% [markdown]
# ---

# %% [markdown]
# # 번외1. kNN Classifier
#
# K-means 알고리즘은 K-NN 알고리즘과 유사하면서도 다르다. 둘은 모두 K개의 점을 지정하여 거리를 기반으로 구현되는 거리기반 분석 알고리즘이다. 하지만 둘의 차이점은 지도학습에 속하는 K-NN 알고리즘과 달리 K-means 알고리즘은 비지도학습 방법에 속한다. 따라서 K-means 알고리즘의 목적을 분류(Classification)라고 하지 않고 군집화(Clustering)라고 한다. 즉, K-NN은 분류 알고리즘, K-means은 군집화 알고리즘이라고 할 수 있다.

# %%
from IPython import display
display.Image("https://s3-ap-northeast-2.amazonaws.com/opentutorials-user-file/module/4916/12316.jpeg")

# %%
topic_df.head()
# Out:
#    Topic #0  Topic #1  Topic #2  Topic #3  Topic #4  Topic #5  Topic #6  Topic #7  Topic #8  Topic #9  Topic #10  dominant_topic  cluster
# 0  0.001653  0.001653  0.001653  0.001653  0.001653  0.001653  0.001653  0.055694  0.001653  0.929429  0.001653   9               1
# 1  0.003135  0.003135  0.003135  0.003135  0.003135  0.003135  0.003135  0.003135  0.003135  0.968651  0.003135   9               1
# 2  0.003135  0.003135  0.003135  0.003135  0.003135  0.003135  0.003135  0.003135  0.003135  0.968652  0.003135   9               1
# 3  0.001443  0.001443  0.001443  0.001443  0.001443  0.001443  0.001443  0.001443  0.001443  0.985570  0.001443   9               1
# 4  0.005348  0.005348  0.005348  0.005349  0.005348  0.005348  0.005348  0.005348  0.005348  0.946521  0.005348   9               1

# %%
X=topic_df.drop(['dominant_topic'],axis=1)
y=topic_df['dominant_topic']

#importing train_test_split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=1/3,random_state=42, stratify=y)

# %%
from sklearn.neighbors import KNeighborsClassifier

test_scores = []
train_scores = []

for i in range(1,15):

    knn = KNeighborsClassifier(i)
    knn.fit(X_train,y_train)
    
    train_scores.append(knn.score(X_train,y_train))
    test_scores.append(knn.score(X_test,y_test))

# %%
import seaborn as sns
sns.set()

plt.figure(figsize=(12,5))

p = sns.lineplot(range(1,15),train_scores,marker='*',label='Train Score')
p = sns.lineplot(range(1,15),test_scores,marker='o',label='Test Score')
# Out:
# ERROR - Exception
# Traceback (most recent call last):
#   File "/home/datascience/conda/generalmachinelearningforcpusonpython3_8v1_0/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_22689/3454806691.py", line 6, in <module>
#     p = sns.lineplot(range(1,15),train_scores,marker='*',label='Train Score')
# TypeError: lineplot() takes from 0 to 1 positional arguments but 2 were given
# TypeError: lineplot() takes from 0 to 1 positional arguments but 2 were given

# %%
#Setup a knn classifier with 4 neighbors
knn = KNeighborsClassifier(4)

knn.fit(X_train,y_train)
knn.score(X_test,y_test)
# Out:
# 0.9810126582278481

# %%
y_pred = knn.predict(X_test)

from sklearn import metrics

cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
p = sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 19.049999999999997, 'Predicted label')

# %%
print(y_pred)
# Out:
# [9 9 4 7 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 9 3 9 9 9 9 7 4 9 9
#  9 9 9 9 9 4 9 9 9 4 9 9 5 9 9 9 3 9 9 2 3 9 9 9 9 9 9 2 9 4 9 9 9 9 9 9 9
#  9 9 9 9 9 9 9 9 9 9 9 9 9 4 9 2 9 9 9 9 9 9 9 3 8 7 9 9 9 2 9 9 9 9 9 9 9
#  9 9 2 3 4 9 9 9 9 9 9 9 9 9 9 9 9 9 9 3 9 9 9 5 9 9 9 9 9 9 9 9 9 9 9 9 9
#  9 9 9 9 9 9 9 9 9 9]

# %%
X.head()
# Out:
#    Topic #0  Topic #1  Topic #2  Topic #3  Topic #4  Topic #5  Topic #6  Topic #7  Topic #8  Topic #9  Topic #10  cluster
# 0  0.001653  0.001653  0.001653  0.001653  0.001653  0.001653  0.001653  0.055694  0.001653  0.929429  0.001653   1
# 1  0.003135  0.003135  0.003135  0.003135  0.003135  0.003135  0.003135  0.003135  0.003135  0.968651  0.003135   1
# 2  0.003135  0.003135  0.003135  0.003135  0.003135  0.003135  0.003135  0.003135  0.003135  0.968652  0.003135   1
# 3  0.001443  0.001443  0.001443  0.001443  0.001443  0.001443  0.001443  0.001443  0.001443  0.985570  0.001443   1
# 4  0.005348  0.005348  0.005348  0.005349  0.005348  0.005348  0.005348  0.005348  0.005348  0.946521  0.005348   1

# %%
# 예측 결과를 데이터프레임으로 변환
y_result = knn.predict(X)
y_result2 = pd.DataFrame(y_result, columns=['Predicted_Label'])
y_result2.head()
# Out:
#    Predicted_Label
# 0  9
# 1  9
# 2  9
# 3  9
# 4  9

# %%
# 기존 데이터와 예측 결과를 열 방향(axis=1)으로 병합
data_with_predictions = pd.concat([topic_df, y_result2], axis=1)

# NaN 값을 가진 행 제거
data_with_predictions = data_with_predictions.dropna()

data_with_predictions.head()
# Out:
#    Topic #0  Topic #1  Topic #2  Topic #3  Topic #4  Topic #5  Topic #6  Topic #7  Topic #8  Topic #9  Topic #10  dominant_topic  cluster  Predicted_Label
# 0  0.001653  0.001653  0.001653  0.001653  0.001653  0.001653  0.001653  0.055694  0.001653  0.929429  0.001653   9.0             1.0      9.0
# 1  0.003135  0.003135  0.003135  0.003135  0.003135  0.003135  0.003135  0.003135  0.003135  0.968651  0.003135   9.0             1.0      9.0
# 2  0.003135  0.003135  0.003135  0.003135  0.003135  0.003135  0.003135  0.003135  0.003135  0.968652  0.003135   9.0             1.0      9.0
# 3  0.001443  0.001443  0.001443  0.001443  0.001443  0.001443  0.001443  0.001443  0.001443  0.985570  0.001443   9.0             1.0      9.0
# 4  0.005348  0.005348  0.005348  0.005349  0.005348  0.005348  0.005348  0.005348  0.005348  0.946521  0.005348   9.0             1.0      9.0

# %%
data_with_predictions.dtypes
data_with_predictions = data_with_predictions.astype({"dominant_topic":'int', "cluster":'int', "Predicted_Label":'int'})

# %%
# 결과 확인
pd.set_option('display.max_columns', None)
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', -1)
print(data_with_predictions)

# %% [markdown]
# ---

# %% [markdown]
# # 번외2. LDA & K-Means & KNN 최종 결과

# %%
from matplotlib.ticker import MaxNLocator
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

scatter = ax.scatter(data_with_predictions['cluster'], data_with_predictions['Predicted_Label'], c=data_with_predictions['dominant_topic'], cmap='viridis')

legend1=plt.legend(*scatter.legend_elements(num=6),bbox_to_anchor=(1.04, 1), borderaxespad=0, title="Topic")

ax.add_artist(legend1)
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

plt.title('Classification Results')
plt.xlabel('cluster')
plt.ylabel('Predicted_Label')

plt.show()
